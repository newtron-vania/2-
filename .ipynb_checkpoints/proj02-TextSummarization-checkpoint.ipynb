# %%
# Selenium 설치.
# !pip install selenium

# %%
import numpy as np
import re

import requests as rq
import bs4
import selenium
from selenium import webdriver

import konlpy

from sklearn.feature_extraction.text import CountVectorizer
import nltk

from selenium import webdriver

# %%
#전처리
def cleaning(argStr):
    argStr = argStr.lower()
    argStr = re.sub(r'\W',  ' ',argStr)
    argStr = re.sub(r'\s+', ' ',argStr)
    argStr = re.sub(r'\s$', '' ,argStr)
    return(argStr)

def oneUrlNews(argLstHl):
    lstHyperLinkNews = []
    for hl in argLstHl:
        hlSubj = hl.find('strong')
        if hlSubj:
            strSubj = hlSubj.text
            if (len(strSubj) > 10):
                lstHyperLinkNews.append(hl)
                
    lstLinkNews = [x.get("href") for x in lstHyperLinkNews]
    
    link = lstLinkNews[np.random.randint(len(lstLinkNews))]
    if "https://news.naver.com" not in link:
        link = "https://news.naver.com" + link
        
    return(link)

# %%
naverNewsUrl = "https://news.naver.com"

def oneTextNews(arUrl):
    driverMy = webdriver.Chrome('chromedriver.exe')
    
    driverMy.get("https://news.naver.com")
    html01 = driverMy.page_source
    soup01 = bs4.BeautifulSoup(html01, 'html.parser')
    lstHyperLink = soup01.find_all('a', class_=re.compile('clicks'))    
    urlTarget = oneUrlNews(lstHyperLink)
    
    driverMy.get(urlTarget)
    html02 = driverMy.page_source
    soup01 = bs4.BeautifulSoup(html02, 'html.parser')
    tagCont = soup01.find("div", id="articleBodyContents")

    driverMy.close()
    
    return cleaning(tagCont.text)
    
strOneNews = oneTextNews(naverNewsUrl)

# %%
strOneNews
# Out:
# ' flash 오류를 우회하기 위한 함수 추가 function _flash_removecallback 평균 보행 속도 시속 4 6km로빨리 걷는 사람보다 느린 속도 영화처럼 차 따라 잡을 수 없어멸종 전까지 약 25억 마리 서식한곳서 무리의 화석 발견되며집단 사냥한 것으로 추정되기도쥐라기 후기 약 250만년 동안 지구를 지배한 티라노사우루스 온전히 발굴된 화석이 32마리밖에 없어 아직도 밝혀지지 않은 부분이 많다 uc버클리 공룡계의 스타는 단연 영화 쥬라기공원 의 로고에도 나오는 티라노사우루스이다 몸길이 12m에 최대 9톤 가까이 가는 몸무게로 모든 동물을 공포에 몰아넣었다 하지만 명성에 비해 아직도 모르는 점이 많다 티라노사우루스는 얼마나 빨랐을까 혼자 다니는 고독한 사냥꾼이었을까 집안을 총동원했을까 최근 과학자들이 그동안 미스터리로 남아 있던 티라노사우루스의 진면목을 잇따라 밝혀냈다 지구에 등장한 티라노는 25억 마리 티라노사우루스는 쥐라기 후기 6800만년 6550만년 전 에 살았다 그 사이 얼마나 많은 공룡이 살았을까 캘리포니아대 uc 샌타바버라의 존 다무스 교수는 동물의 개체 밀도를 신체 크기와 연관지었다 즉 같은 면적에 쥐보다 코끼리의 수가 적다는 이른바 다무스의 법칙 이다 uc버클리의 찰스 마셜 교수는 지난 16일 사이언스 에 다무스 법칙을 근거로 티라노사우루스의 개체 밀도를 100 당 약 1마리로 계산했다 캘리포니아주만 한 면적에 3800마리쯤 사는 셈이다 오늘날 북미 대륙 전체에 동시에 살았던 개체 수는 약 2만 마리가 된다 또 티라노사우루스의 한 세대가 19년이므로 멸종에 이르기까지 250만 년 동안 12만7000세대에 걸쳐 총 25억마리가 살았다고 볼 수 있다 그럼에도 화석으로 발굴된 티라노사우루스는 32마리에 그친다 그만큼 대형 육식공룡이 화석으로 남기가 어렵다는 말이다 공룡의 제왕 티라노사우루스 미스터리 2014년 미국 토지관리국의 고생물학자인 앨런 티투스 박사는 유타주 남부에서 티라노사우루스 무리의 화석을 발굴했다 어른 공룡 1마리와 젊은 공룡 1마리 어린 공룡 3마리였다 티투스 박사와 아칸소대의 셀리나 수아레즈 교수 공동 연구진은 지난 19일 국제 학술지 피어제이 peerj 에 연대측정을 통해 공룡 가족이 동시에 홍수로 화석이 됐으며 이는 티라노사우루스가 오늘날 늑대처럼 가족이 함께 살면서 사냥도 같이 한 증거가 된다 고 밝혔다 앞서 캐나다와 미국 몬태나주에서도 티라노사우루스 무리 화석이 발굴된 적이 있다 하지만 공룡의 두뇌가 집단 사냥을 할만큼 발달했다고 보기 어렵다는 비판도 있다 피부 덮은 것은 털일까 비늘일까 영화를 보면 티라노사우루스가 사람들이 탄 차를 따라잡는 장면이 나온다 네덜란드 암스테르담 자유대 연구진은 지난 21일 왕립학회 오픈 사이언스 에 티라노사우루스의 보행 속도는 시속 5 가 채 되지 않았다고 밝혔다 사람이 빨리 걸으면 도망갈 수 있다는 말이다 과학자들은 공룡의 몸무게와 엉덩이 높이 발자국 화석을 토대로 티라노사우루스의 보행 속도를 시속 7 2 10 8 로 추산했다 하지만 네덜란드 연구진은 몸무게와 키보다 꼬리에 주목했다 공룡 꼬리가 위아래로 흔들리면서 균형을 잡아주고 몸이 앞으로 가게 해준다는 것이다 연구진은 네덜란드에 있는 티라노사우루스 화석의 꼬리를 토대로 공룡의 컴퓨터 모델을 만들었다 꼬리 근육의 탄성과 흔들리는 주기를 감안하면 평균 보행 속도는 시속 4 6 로 나왔다 달리기는 이전보다 더 빠를 수 있다 티라노사우루스의 주행 속도는 시속 16 40 로 추정됐다 그보다 빠르면 뼈가 부서진다고 봤다 반면 네덜란드 연구진은 꼬리가 충격을 흡수한다면 뼈 손상 없이 더 빨리 뛸 수 있다고 밝혔다 티라노사우루스의 꼬리 근육을 토대로 재구성한 보행 모습 시속 4 6km로 사람보다 빠르지 않았던 것으로 추정된다 네덜란드 암스테르담 자유대 1993년 쥬라기공원 개봉 후 가장 크게 변한 공룡의 이미지는 털이다 한 예로 2012년 몸길이 9m의 대형 육식공룡 유티라누스가 털로 덮였다는 연구 결과가 나왔다 그 뒤에 나온 사촌 격인 티라노사우루스도 털이 있었을까 2017년 미국 휴스턴 자연사박물관 연구진은 유일한 티라노사우루스의 피부 화석을 조사했더니 목과 골반 꼬리에 털은 없고 비늘만 있었다고 밝혔다 연구진은 티라노사우루스는 열을 잘 보존할 수 있어 이전에 단열 역할을 하던 털이 사라졌다고 추정했다 만약 털이 있다면 등에만 일부 남았을 것이라고 주장했다 이영완 과학전문기자 ywlee chosun com 조선일보가 뽑은 뉴스 확인해보세요 최고 기자들의 뉴스레터 받아보세요 1등 신문 조선일보 앱으로 편하게 보세요'

# %%
kkma = konlpy.tag.Kkma()
lstSent = kkma.sentences(strOneNews)
lstSent
# Out:
# ['flash 오류를 우회하기 위한 함수 추가 function _flash _removecallback 평균 보행 속도 시속 4 6km로 빨리 걷는 사람보다 느린 속도 영화처럼 차 따라 잡을 수 없어 멸종 전까지 약 25억 마리 서식한 곳서 무리의 화석 발견되며 집단 사냥한 것으로 추정되기도 쥐라기 후기 약 250만년 동안 지구를 지배한 티 라 노사 우 루스 온전히 발굴된 화석이 32마리밖에 없어 아직도 밝혀지지 않은 부분이 많다',
#  'uc 버클리 공룡 계의 스타는 단연 영화 쥬라기공원 의 로고에도 나오는 티 라 노사 우 루스이다 몸길이 12m에 최대 9톤 가까이 가는 몸무게로 모든 동물을 공포에 몰아넣었다 하지만 명성에 비해 아직도 모르는 점이 많다 티라 노 사우 루스는 얼마나 빨랐을까',
#  '혼자 다니는 고독한 사냥꾼이었을까',
#  '집안을 총동원했을까',
#  '최근 과학자들이 그동안 미스터리로 남아 있던 티 라 노사 우 루스의 진면목을 잇따라 밝혀냈다 지구에 등장한 티라 노는 25억 마리 티라 노 사우루 스는 쥐라기 후기 6800만년 6550만년 전에 살았다 그 사이 얼마나 많은 공룡이 살았을까',
#  '캘리포니아 대 uc 샌 타 바 버라의 존 다 무스 교수는 동물의 개체 밀도를 신체 크기와 연관지었다 즉 같은 면적에 쥐보다 코끼리의 수가 적다는 이른바 다 무스의 법 칙 이다',
#  'uc 버클리의 찰스 마 셜 교수는 지난 16 일 사이언스에 다 무스 법칙을 근거로 티라 노 사우 루스의 개체 밀도를 100 당 약 1마리로 계산했다 캘리포니아 주만 한 면적에 3800마리 쯤 사는 셈이다 오늘날 북미 대륙 전체에 동시에 살았던 개체 수는 약 2만 마리가 된다 또 티라 노 사우 루스의 한 세대가 19년이므로 멸종에 이르기까지 250만 년 동안 12만 7000 세대에 걸쳐 총 25억마리가 살았다고',
#  '볼 수 있다 그럼에도 화석으로 발굴된 티 라 노사 우 루스는 32마리에 그친다 그만큼 대형 육식 공룡이 화석으로 남기가 어렵다는 말이다 공룡의 제왕 티 라 노사 우 루스 미스터리 2014년 미국 토지 관리국의 고생물학자인 앨 런 티투스 박사는 유타주 남부에서 티라 노 사우 루스 무리의 화석을 발굴했다 어른 공룡 1마리와 젊은 공룡 1마리 어린 공룡 3마리였다 티투스 박사와 아칸소 대의 셀 리나 수 아 레 즈 교수 공동 연구진은 지난 19일 국제 학술지 피어 제이 peerj 에 연대 측정을 통해 공룡 가족이 동시에 홍수로 화석이 됐으며 이는 티라 노 사우 루스가 오늘날 늑대처럼 가족이 함께 살면서 사냥도 같이 한 증거가 된다 고 밝혔다 앞서 캐나다와 미국 몬태나 주에서도 티라 노 사우 루스 무리 화석이 발굴된 적이 있다 하지만 공룡의 두뇌가 집단 사냥을 할 만큼 발달했다고',
#  '보기 어렵다는 비판도 있다 피부 덮은 것은 털일까 비늘일까 영화를 보면 티라 노 사우 루스가 사람들이 탄 차를 따라잡는 장면이 나온다 네덜란드 암 스테르담 자유 대 연구진은 지난 21일 왕립학회 오픈 사이언스에 티라 노 사우 루스의 보행 속도는 시속 5 가 채 되지 않았다고',
#  '밝혔다 사람이 빨리 걸으면 도망갈 수 있다는 말이다 과학자들은 공룡의 몸무게와 엉덩이 높이 발자국 화석을 토대로 티라 노 사우 루스의 보행 속도를 시속 7 2 10 8 로 추산했다 하지만 네덜란드 연구진은 몸무게와 키보다 꼬리에 주목했다 공룡 꼬리가 위아래로 흔들리면서 균형을 잡아 주고 몸이 앞으로 가게 해 준다는 것이다 연구진은 네덜란드에 있는 티 라 노사 우 루스 화석의 꼬리를 토대로 공룡의 컴퓨터 모델을 만들었다 꼬리 근육의 탄성과 흔들리는 주기를 감안 하면 평균 보행 속도는 시속 4 6 로 나왔다 달리기는 이전보다 더 빠를 수 있다 티라 노 사우 루스의 주행 속도는 시속 16 40 로 추정됐다 그보다 빠르면 뼈가 부서진다고 봤다 반면 네덜란드 연구진은 꼬리가 충격을 흡수한다면 뼈 손상 없이 더 빨리 뛸 수 있다고',
#  '밝혔다 티라 노 사우 루스의 꼬리 근육을 토대로 재구성한 보행 모습 시속 4 6km 로 사람보다 빠르지 않았던 것으로 추정된다 네덜란드 암 스테르담 자유 대 1993 년 쥬라기공원 개봉 후 가장 크게 변한 공룡의 이미지는 털이다 한 예로 2012년 몸길이 9m 의 대형 육식 공룡 유 티라 누스가 털로 덮였다는 연구 결과가 나왔다 그 뒤에 나온 사촌 격인 티 라 노사 우 루스도 털이 있었을까',
#  '2017년 미국 휴스턴 자연사박물관 연구진은 유일한 티 라 노사 우 루스의 피부 화석을 조사했더니 목과 골반 꼬리에 털은 없고 비늘만 있었다고',
#  '밝혔다 연구진은 티라 노 사우루 스는 열을 잘 보존할 수 있어 이전에 단열 역할을 하던 털이 사라졌다고 추정했다 만약 털이 있다면 등에만 일부 남았을 것이라고 주장했다 이영 완 과학전문기자 ywlee chosun com 조선 일보가 뽑은 뉴스 확인해 보세요 최고 기자들의 뉴스 레터 받아 보세요',
#  '1등 신문 조선 일보 앱으로 편하게 보세요']

# %%
lstPosSent = []
for x in lstSent:
    lstPosSent.append(kkma.pos(x))
lstPosSent
# Out:
# [[('flash', 'OL'),
#   ('오류', 'NNG'),
#   ('를', 'JKO'),
#   ('우회', 'NNG'),
#   ('하', 'XSV'),
#   ('기', 'ETN'),
#   ('위하', 'VV'),
#   ('ㄴ', 'ETD'),
#   ('함수', 'NNG'),
#   ('추가', 'NNG'),
#   ('function', 'OL'),
#   ('_', 'SW'),
#   ('flash', 'OL'),
#   ('_', 'SW'),
#   ('removecallback', 'OL'),
#   ('평균', 'NNG'),
#   ('보행', 'NNG'),
#   ('속', 'NNG'),
#   ('도', 'JX'),
#   ('시속', 'NNG'),
#   ('4', 'NR'),
#   ('6', 'NR'),
#   ('km', 'OL'),
#   ('로', 'JKM'),
#   ('빨리', 'MAG'),
#   ('걷', 'VV'),
#   ('는', 'ETD'),
#   ('사람', 'NNG'),
#   ('보다', 'JKM'),
#   ('느리', 'VA'),
#   ('ㄴ', 'ETD'),
#   ('속도', 'NNG'),
#   ('영화', 'NNG'),
#   ('처럼', 'JKM'),
#   ('차', 'NNG'),
#   ('따르', 'VV'),
#   ('아', 'ECS'),
#   ('잡', 'VV'),
#   ('을', 'ETD'),
#   ('수', 'NNB'),
#   ('없', 'VA'),
#   ('어', 'ECD'),
#   ('멸종', 'NNG'),
#   ('전', 'NNG'),
#   ('까지', 'JX'),
#   ('약', 'MDN'),
#   ('25', 'NR'),
#   ('억', 'NR'),
#   ('마리', 'NNB'),
#   ('서식', 'NNG'),
#   ('하', 'XSV'),
#   ('ㄴ', 'ETD'),
#   ('곳', 'NNG'),
#   ('서', 'JKM'),
#   ('무리', 'NNG'),
#   ('의', 'JKG'),
#   ('화석', 'NNG'),
#   ('발견', 'NNG'),
#   ('되', 'XSV'),
#   ('며', 'ECE'),
#   ('집단', 'NNG'),
#   ('사냥', 'NNG'),
#   ('하', 'XSV'),
#   ('ㄴ', 'ETD'),
#   ('것', 'NNB'),
#   ('으로', 'JKM'),
#   ('추정', 'NNG'),
#   ('되', 'XSV'),
#   ('기', 'ETN'),
#   ('도', 'JX'),
#   ('쥐라기', 'NNG'),
#   ('후기', 'NNG'),
#   ('약', 'NNG'),
#   ('250', 'NR'),
#   ('만', 'NR'),
#   ('년', 'NNM'),
#   ('동안', 'NNG'),
#   ('지구', 'NNG'),
#   ('를', 'JKO'),
#   ('지배', 'NNG'),
#   ('하', 'XSV'),
#   ('ㄴ', 'ETD'),
#   ('티', 'NNG'),
#   ('라', 'NNG'),
#   ('노사', 'NNG'),
#   ('우', 'NNG'),
#   ('루스', 'NNG'),
#   ('온전히', 'MAG'),
#   ('발굴', 'NNG'),
#   ('되', 'XSV'),
#   ('ㄴ', 'ETD'),
#   ('화석', 'NNG'),
#   ('이', 'JKS'),
#   ('32', 'NR'),
#   ('마리', 'NNM'),
#   ('밖에', 'JX'),
#   ('없', 'VA'),
#   ('어', 'ECD'),
#   ('아직', 'MAG'),
#   ('도', 'JX'),
#   ('밝혀지', 'VV'),
#   ('지', 'ECD'),
#   ('않', 'VXV'),
#   ('은', 'ETD'),
#   ('부분', 'NNG'),
#   ('이', 'JKS'),
#   ('많', 'VA'),
#   ('다', 'EFN')],
#  [('uc', 'OL'),
#   ('버클리', 'NNG'),
#   ('공룡', 'NNG'),
#   ('계의', 'NNG'),
#   ('스타', 'NNG'),
#   ('는', 'JX'),
#   ('단연', 'MAG'),
#   ('영화', 'NNG'),
#   ('쥬라기', 'NNG'),
#   ('공원', 'NNG'),
#   ('의', 'NNG'),
#   ('로고', 'NNG'),
#   ('에', 'JKM'),
#   ('도', 'JX'),
#   ('나오', 'VV'),
#   ('는', 'ETD'),
#   ('티', 'NNG'),
#   ('라', 'NNG'),
#   ('노사', 'NNG'),
#   ('우', 'NNG'),
#   ('루스', 'NNG'),
#   ('이', 'VCP'),
#   ('다', 'ECS'),
#   ('몸길이', 'NNG'),
#   ('12', 'NR'),
#   ('m', 'OL'),
#   ('에', 'JKM'),
#   ('최대', 'NNG'),
#   ('9', 'NR'),
#   ('톤', 'NNM'),
#   ('가까이', 'MAG'),
#   ('갈', 'VV'),
#   ('는', 'ETD'),
#   ('몸무게', 'NNG'),
#   ('로', 'JKM'),
#   ('모든', 'MDT'),
#   ('동물', 'NNG'),
#   ('을', 'JKO'),
#   ('공포', 'NNG'),
#   ('에', 'JKM'),
#   ('몰아넣', 'VV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('하지만', 'MAC'),
#   ('명성', 'NNG'),
#   ('에', 'JKM'),
#   ('비하', 'VV'),
#   ('어', 'ECS'),
#   ('아직', 'MAG'),
#   ('도', 'JX'),
#   ('모르', 'VV'),
#   ('는', 'ETD'),
#   ('점', 'NNG'),
#   ('이', 'JKS'),
#   ('많', 'VA'),
#   ('다', 'ECS'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('루스', 'NNG'),
#   ('는', 'JX'),
#   ('얼마나', 'MAG'),
#   ('빠르', 'VA'),
#   ('았', 'EPT'),
#   ('을까', 'EFQ')],
#  [('혼자', 'NNG'),
#   ('다니', 'VV'),
#   ('는', 'ETD'),
#   ('고독', 'NNG'),
#   ('하', 'XSV'),
#   ('ㄴ', 'ETD'),
#   ('사냥꾼', 'NNG'),
#   ('이', 'VCP'),
#   ('었', 'EPT'),
#   ('을까', 'EFQ')],
#  [('집안', 'NNG'),
#   ('을', 'JKO'),
#   ('총동원', 'NNG'),
#   ('하', 'XSV'),
#   ('었', 'EPT'),
#   ('을까', 'EFQ')],
#  [('최근', 'NNG'),
#   ('과학자', 'NNG'),
#   ('들', 'XSN'),
#   ('이', 'JKS'),
#   ('그동안', 'NNG'),
#   ('미스터리', 'NNG'),
#   ('로', 'JKM'),
#   ('남', 'VV'),
#   ('아', 'ECD'),
#   ('있', 'VXV'),
#   ('더', 'EPT'),
#   ('ㄴ', 'ETD'),
#   ('티', 'NNG'),
#   ('라', 'NNG'),
#   ('노사', 'NNG'),
#   ('우', 'NNG'),
#   ('루스', 'NNG'),
#   ('의', 'JKG'),
#   ('진면목', 'NNG'),
#   ('을', 'JKO'),
#   ('잇따르', 'VV'),
#   ('아', 'ECS'),
#   ('밝혀내', 'VV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('지구', 'NNG'),
#   ('에', 'JKM'),
#   ('등장', 'NNG'),
#   ('하', 'XSV'),
#   ('ㄴ', 'ETD'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('놀', 'VV'),
#   ('는', 'ETD'),
#   ('25', 'NR'),
#   ('억', 'NR'),
#   ('마리', 'NNB'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('로', 'JKM'),
#   ('스', 'VV'),
#   ('는', 'ETD'),
#   ('쥐라기', 'NNG'),
#   ('후기', 'NNG'),
#   ('6800', 'NR'),
#   ('만', 'NR'),
#   ('년', 'NNM'),
#   ('6550', 'NR'),
#   ('만', 'NR'),
#   ('년', 'NNM'),
#   ('전', 'NNG'),
#   ('에', 'JKM'),
#   ('살', 'VV'),
#   ('았', 'EPT'),
#   ('다', 'ECS'),
#   ('그', 'MDT'),
#   ('사이', 'NNG'),
#   ('얼마나', 'MAG'),
#   ('많', 'VA'),
#   ('은', 'ETD'),
#   ('공룡', 'NNG'),
#   ('이', 'JKS'),
#   ('살', 'VV'),
#   ('았', 'EPT'),
#   ('을까', 'EFQ')],
#  [('캘리포니아', 'NNG'),
#   ('대', 'NNB'),
#   ('uc', 'OL'),
#   ('새', 'VV'),
#   ('ㄴ', 'ETD'),
#   ('타', 'NNG'),
#   ('바', 'NNG'),
#   ('버라', 'UN'),
#   ('의', 'JKG'),
#   ('존', 'NNP'),
#   ('다', 'MAG'),
#   ('무스', 'NNG'),
#   ('교수', 'NNG'),
#   ('는', 'JX'),
#   ('동물', 'NNG'),
#   ('의', 'JKG'),
#   ('개체', 'NNG'),
#   ('밀도', 'NNG'),
#   ('를', 'JKO'),
#   ('신체', 'NNG'),
#   ('크기', 'NNG'),
#   ('와', 'JKM'),
#   ('연관짓', 'VV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('즉', 'MAG'),
#   ('같', 'VA'),
#   ('은', 'ETD'),
#   ('면적', 'NNG'),
#   ('에', 'JKM'),
#   ('쥐', 'NNG'),
#   ('보다', 'JKM'),
#   ('코끼리', 'NNG'),
#   ('의', 'JKG'),
#   ('수가', 'NNG'),
#   ('적', 'VA'),
#   ('다는', 'ETD'),
#   ('이른바', 'MAG'),
#   ('다', 'MAG'),
#   ('무스', 'NNG'),
#   ('의', 'JKG'),
#   ('법', 'NNG'),
#   ('칙', 'UN'),
#   ('이', 'VCP'),
#   ('다', 'EFN')],
#  [('uc', 'OL'),
#   ('버클리', 'NNG'),
#   ('의', 'JKG'),
#   ('찰스', 'UN'),
#   ('마', 'NNG'),
#   ('셜', 'UN'),
#   ('교수', 'NNG'),
#   ('는', 'JX'),
#   ('지나', 'VV'),
#   ('ㄴ', 'ETD'),
#   ('16', 'NR'),
#   ('일', 'NNG'),
#   ('사이언스', 'NNG'),
#   ('에', 'JKM'),
#   ('다', 'MAG'),
#   ('무스', 'NNG'),
#   ('법칙', 'NNG'),
#   ('을', 'JKO'),
#   ('근거', 'NNG'),
#   ('로', 'JKM'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('루스', 'NNG'),
#   ('의', 'JKG'),
#   ('개체', 'NNG'),
#   ('밀도', 'NNG'),
#   ('를', 'JKO'),
#   ('100', 'NR'),
#   ('당', 'NNG'),
#   ('약', 'NNG'),
#   ('1', 'NR'),
#   ('마리', 'NNM'),
#   ('로', 'JKM'),
#   ('계산', 'NNG'),
#   ('하', 'XSV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('캘리포니아', 'NNG'),
#   ('주', 'NNG'),
#   ('만', 'JX'),
#   ('한', 'NNG'),
#   ('면적', 'NNG'),
#   ('에', 'JKM'),
#   ('3800', 'NR'),
#   ('마리', 'NNM'),
#   ('쯤', 'NNG'),
#   ('사', 'VV'),
#   ('는', 'ETD'),
#   ('셈', 'NNB'),
#   ('이', 'VCP'),
#   ('다', 'ECS'),
#   ('오늘날', 'NNG'),
#   ('북미', 'NNG'),
#   ('대륙', 'NNG'),
#   ('전체', 'NNG'),
#   ('에', 'JKM'),
#   ('동시', 'NNG'),
#   ('에', 'JKM'),
#   ('살', 'VV'),
#   ('았', 'EPT'),
#   ('더', 'EPT'),
#   ('ㄴ', 'ETD'),
#   ('개체', 'NNG'),
#   ('수', 'NNG'),
#   ('는', 'JX'),
#   ('약', 'MDN'),
#   ('2', 'NR'),
#   ('만', 'NR'),
#   ('마리', 'NNB'),
#   ('가', 'JKC'),
#   ('되', 'VV'),
#   ('ㄴ다', 'ECS'),
#   ('또', 'MAG'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('루스', 'NNG'),
#   ('의', 'JKG'),
#   ('한', 'MDN'),
#   ('세대', 'NNG'),
#   ('가', 'JKS'),
#   ('19', 'NR'),
#   ('년', 'NNM'),
#   ('이', 'VCP'),
#   ('므로', 'ECD'),
#   ('멸종', 'NNG'),
#   ('에', 'JKM'),
#   ('이르', 'VV'),
#   ('기', 'ETN'),
#   ('까지', 'JX'),
#   ('250', 'NR'),
#   ('만', 'NR'),
#   ('년', 'NNB'),
#   ('동안', 'NNG'),
#   ('12', 'NR'),
#   ('만', 'NR'),
#   ('7000', 'NR'),
#   ('세대', 'NNG'),
#   ('에', 'JKM'),
#   ('걸치', 'VV'),
#   ('어', 'ECS'),
#   ('총', 'NNG'),
#   ('25', 'NR'),
#   ('억', 'NR'),
#   ('마리', 'NNM'),
#   ('가', 'JKS'),
#   ('살', 'VV'),
#   ('았', 'EPT'),
#   ('다고', 'EFN')],
#  [('보', 'VV'),
#   ('ㄹ', 'ETD'),
#   ('수', 'NNB'),
#   ('있', 'VV'),
#   ('다', 'ECS'),
#   ('그러', 'VV'),
#   ('ㅁ에도', 'ECD'),
#   ('화석', 'NNG'),
#   ('으로', 'JKM'),
#   ('발굴', 'NNG'),
#   ('되', 'XSV'),
#   ('ㄴ', 'ETD'),
#   ('티', 'NNG'),
#   ('라', 'NNG'),
#   ('노사', 'NNG'),
#   ('우', 'NNG'),
#   ('루스', 'NNG'),
#   ('는', 'JX'),
#   ('32', 'NR'),
#   ('마리', 'NNM'),
#   ('에', 'JKM'),
#   ('그치', 'VV'),
#   ('ㄴ다', 'ECS'),
#   ('그만큼', 'MAG'),
#   ('대형', 'NNG'),
#   ('육식', 'NNG'),
#   ('공룡', 'NNG'),
#   ('이', 'JKS'),
#   ('화석', 'NNG'),
#   ('으로', 'JKM'),
#   ('남기', 'NNG'),
#   ('가', 'JKS'),
#   ('어렵', 'VA'),
#   ('다는', 'ETD'),
#   ('말', 'NNG'),
#   ('이', 'VCP'),
#   ('다', 'ECS'),
#   ('공룡', 'NNG'),
#   ('의', 'JKG'),
#   ('제왕', 'NNG'),
#   ('티', 'NNG'),
#   ('라', 'NNG'),
#   ('노사', 'NNG'),
#   ('우', 'NNG'),
#   ('루스', 'NNG'),
#   ('미스터리', 'NNG'),
#   ('2014', 'NR'),
#   ('년', 'NNM'),
#   ('미국', 'NNP'),
#   ('토지', 'NNG'),
#   ('관리국', 'NNG'),
#   ('의', 'JKG'),
#   ('고생물', 'NNG'),
#   ('학자', 'NNG'),
#   ('이', 'VCP'),
#   ('ㄴ', 'ETD'),
#   ('앨', 'UN'),
#   ('런', 'NNG'),
#   ('티투스', 'NNG'),
#   ('박사', 'NNG'),
#   ('는', 'JX'),
#   ('유타주', 'NNG'),
#   ('남부', 'NNG'),
#   ('에서', 'JKM'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('루스', 'NNG'),
#   ('무리', 'NNG'),
#   ('의', 'JKG'),
#   ('화석', 'NNG'),
#   ('을', 'JKO'),
#   ('발굴', 'NNG'),
#   ('하', 'XSV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('어르', 'VV'),
#   ('ㄴ', 'ETD'),
#   ('공룡', 'NNG'),
#   ('1', 'NR'),
#   ('마리', 'NNM'),
#   ('와', 'JKM'),
#   ('젊', 'VA'),
#   ('은', 'ETD'),
#   ('공룡', 'NNG'),
#   ('1', 'NR'),
#   ('마리', 'NNM'),
#   ('어리', 'VA'),
#   ('ㄴ', 'ETD'),
#   ('공룡', 'NNG'),
#   ('3', 'NR'),
#   ('마리', 'NNM'),
#   ('이', 'VCP'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('티투스', 'NNG'),
#   ('박사', 'NNG'),
#   ('와', 'JC'),
#   ('아칸소', 'NNG'),
#   ('대의', 'NNG'),
#   ('셀', 'NNG'),
#   ('리', 'NNG'),
#   ('나', 'JC'),
#   ('수', 'NNG'),
#   ('아', 'VV'),
#   ('아', 'ECS'),
#   ('레', 'NNG'),
#   ('즈', 'UN'),
#   ('교수', 'NNG'),
#   ('공동', 'NNG'),
#   ('연구진', 'NNG'),
#   ('은', 'JX'),
#   ('지나', 'VV'),
#   ('ㄴ', 'ETD'),
#   ('19', 'NR'),
#   ('일', 'NNM'),
#   ('국제', 'NNG'),
#   ('학술지', 'NNG'),
#   ('피어', 'NNG'),
#   ('제이', 'NNG'),
#   ('peerj', 'OL'),
#   ('에', 'JKM'),
#   ('연대', 'NNG'),
#   ('측정', 'NNG'),
#   ('을', 'JKO'),
#   ('통하', 'VV'),
#   ('어', 'ECS'),
#   ('공룡', 'NNG'),
#   ('가족', 'NNG'),
#   ('이', 'JKS'),
#   ('동시', 'NNG'),
#   ('에', 'JKM'),
#   ('홍수', 'NNG'),
#   ('로', 'JKM'),
#   ('화석', 'NNG'),
#   ('이', 'JKC'),
#   ('되', 'VV'),
#   ('었', 'EPT'),
#   ('으며', 'ECE'),
#   ('이', 'NP'),
#   ('는', 'JX'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('루스', 'NNG'),
#   ('가', 'JKS'),
#   ('오늘날', 'NNG'),
#   ('늑대', 'NNG'),
#   ('처럼', 'JKM'),
#   ('가족', 'NNG'),
#   ('이', 'JKS'),
#   ('함께', 'MAG'),
#   ('살', 'VV'),
#   ('면서', 'ECE'),
#   ('사냥', 'NNG'),
#   ('도', 'JX'),
#   ('같이', 'MAG'),
#   ('하', 'VV'),
#   ('ㄴ', 'ETD'),
#   ('증거', 'NNG'),
#   ('가', 'JKC'),
#   ('되', 'VV'),
#   ('ㄴ다', 'ECS'),
#   ('이', 'VCP'),
#   ('고', 'ECE'),
#   ('밝히', 'VV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('앞서', 'MAG'),
#   ('캐나다', 'NNG'),
#   ('와', 'JC'),
#   ('미국', 'NNP'),
#   ('몬태나', 'NNG'),
#   ('주', 'NNG'),
#   ('에서', 'JKM'),
#   ('도', 'JX'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('루스', 'NNG'),
#   ('무리', 'NNG'),
#   ('화석', 'NNG'),
#   ('이', 'JKS'),
#   ('발굴', 'NNG'),
#   ('되', 'XSV'),
#   ('ㄴ', 'ETD'),
#   ('적이', 'MAG'),
#   ('있', 'VV'),
#   ('다', 'ECS'),
#   ('하지만', 'MAC'),
#   ('공룡', 'NNG'),
#   ('의', 'JKG'),
#   ('두뇌', 'NNG'),
#   ('가', 'JKS'),
#   ('집단', 'NNG'),
#   ('사냥', 'NNG'),
#   ('을', 'JKO'),
#   ('하', 'VV'),
#   ('ㄹ', 'ETD'),
#   ('만큼', 'NNG'),
#   ('발달', 'NNG'),
#   ('하', 'XSV'),
#   ('었', 'EPT'),
#   ('다고', 'EFN')],
#  [('보', 'VV'),
#   ('기', 'ETN'),
#   ('어렵', 'VA'),
#   ('다는', 'ETD'),
#   ('비판', 'NNG'),
#   ('도', 'JX'),
#   ('있다', 'MAG'),
#   ('피부', 'NNG'),
#   ('덮', 'VV'),
#   ('은', 'ETD'),
#   ('것', 'NNB'),
#   ('은', 'JX'),
#   ('털', 'NNG'),
#   ('이', 'VCP'),
#   ('ㄹ까', 'ECD'),
#   ('비늘', 'NNG'),
#   ('이', 'VCP'),
#   ('ㄹ까', 'ECD'),
#   ('영화', 'NNG'),
#   ('를', 'JKO'),
#   ('보', 'VV'),
#   ('면', 'ECE'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('루스', 'NNG'),
#   ('가', 'JKS'),
#   ('사람', 'NNG'),
#   ('들', 'XSN'),
#   ('이', 'JKS'),
#   ('타', 'VV'),
#   ('ㄴ', 'ETD'),
#   ('차', 'NNG'),
#   ('를', 'JKO'),
#   ('따라잡', 'VV'),
#   ('는', 'ETD'),
#   ('장면', 'NNG'),
#   ('이', 'JKS'),
#   ('나오', 'VV'),
#   ('ㄴ다', 'ECS'),
#   ('네덜란드', 'NNG'),
#   ('암', 'NNG'),
#   ('스테르', 'NNG'),
#   ('담', 'XSN'),
#   ('자유', 'NNG'),
#   ('대', 'NNG'),
#   ('연구진', 'NNG'),
#   ('은', 'JX'),
#   ('지나', 'VV'),
#   ('ㄴ', 'ETD'),
#   ('21', 'NR'),
#   ('일', 'NNM'),
#   ('왕립', 'NNG'),
#   ('학회', 'NNG'),
#   ('오픈', 'NNG'),
#   ('사이언스', 'NNG'),
#   ('에', 'JKM'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('루스', 'NNG'),
#   ('의', 'JKG'),
#   ('보행', 'NNG'),
#   ('속도', 'NNG'),
#   ('는', 'JX'),
#   ('시속', 'NNG'),
#   ('5', 'NR'),
#   ('가', 'VV'),
#   ('아', 'ECS'),
#   ('채', 'MAG'),
#   ('되', 'VV'),
#   ('지', 'ECD'),
#   ('않', 'VXV'),
#   ('았', 'EPT'),
#   ('다고', 'EFN')],
#  [('밝히', 'VV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('사람', 'NNG'),
#   ('이', 'JKS'),
#   ('빨리', 'MAG'),
#   ('걷', 'VV'),
#   ('으면', 'ECD'),
#   ('도망가', 'VV'),
#   ('ㄹ', 'ETD'),
#   ('수', 'NNB'),
#   ('있', 'VV'),
#   ('다는', 'ETD'),
#   ('말', 'NNG'),
#   ('이', 'VCP'),
#   ('다', 'ECS'),
#   ('과학자', 'NNG'),
#   ('들', 'XSN'),
#   ('은', 'JX'),
#   ('공룡', 'NNG'),
#   ('의', 'JKG'),
#   ('몸무게', 'NNG'),
#   ('와', 'JC'),
#   ('엉덩이', 'NNG'),
#   ('높이', 'NNG'),
#   ('발자국', 'NNG'),
#   ('화석', 'NNG'),
#   ('을', 'JKO'),
#   ('토대', 'NNG'),
#   ('로', 'JKM'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('루스', 'NNG'),
#   ('의', 'JKG'),
#   ('보행', 'NNG'),
#   ('속도', 'NNG'),
#   ('를', 'JKO'),
#   ('시속', 'NNG'),
#   ('7', 'NR'),
#   ('2', 'NR'),
#   ('10', 'NR'),
#   ('8', 'NR'),
#   ('로', 'NNG'),
#   ('추산', 'NNG'),
#   ('하', 'XSV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('하지만', 'MAC'),
#   ('네덜란드', 'NNG'),
#   ('연구진', 'NNG'),
#   ('은', 'JX'),
#   ('몸무게', 'NNG'),
#   ('와', 'JKM'),
#   ('키', 'NNG'),
#   ('보다', 'JKM'),
#   ('꼬리', 'NNG'),
#   ('에', 'JKM'),
#   ('주목', 'NNG'),
#   ('하', 'XSV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('공룡', 'NNG'),
#   ('꼬리', 'NNG'),
#   ('가', 'JKS'),
#   ('위아래', 'NNG'),
#   ('로', 'JKM'),
#   ('흔들리', 'VV'),
#   ('면서', 'ECE'),
#   ('균형', 'NNG'),
#   ('을', 'JKO'),
#   ('잡', 'VV'),
#   ('아', 'ECD'),
#   ('주', 'VXV'),
#   ('고', 'ECE'),
#   ('몸', 'NNG'),
#   ('이', 'JKS'),
#   ('앞', 'NNG'),
#   ('으로', 'JKM'),
#   ('가', 'VV'),
#   ('게', 'ECD'),
#   ('하', 'VV'),
#   ('어', 'ECS'),
#   ('주', 'VXV'),
#   ('ㄴ다는', 'ETD'),
#   ('것', 'NNB'),
#   ('이', 'VCP'),
#   ('다', 'ECS'),
#   ('연구진', 'NNG'),
#   ('은', 'JX'),
#   ('네덜란드', 'NNG'),
#   ('에', 'JKM'),
#   ('있', 'VV'),
#   ('는', 'ETD'),
#   ('티', 'NNG'),
#   ('라', 'NNG'),
#   ('노사', 'NNG'),
#   ('우', 'NNG'),
#   ('루스', 'NNG'),
#   ('화석', 'NNG'),
#   ('의', 'JKG'),
#   ('꼬리', 'NNG'),
#   ('를', 'JKO'),
#   ('토대', 'NNG'),
#   ('로', 'JKM'),
#   ('공룡', 'NNG'),
#   ('의', 'JKG'),
#   ('컴퓨터', 'NNG'),
#   ('모델', 'NNG'),
#   ('을', 'JKO'),
#   ('만들', 'VV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('꼬리', 'NNG'),
#   ('근육', 'NNG'),
#   ('의', 'JKG'),
#   ('탄성', 'NNG'),
#   ('과', 'JKM'),
#   ('흔들리', 'VV'),
#   ('는', 'ETD'),
#   ('주기', 'NNG'),
#   ('를', 'JKO'),
#   ('감안', 'NNG'),
#   ('하면', 'NNP'),
#   ('평균', 'NNG'),
#   ('보행', 'NNG'),
#   ('속도', 'NNG'),
#   ('는', 'JX'),
#   ('시속', 'NNG'),
#   ('4', 'NR'),
#   ('6', 'NR'),
#   ('로', 'NNG'),
#   ('나오', 'VV'),
#   ('았', 'EPT'),
#   ('다', 'ECS'),
#   ('달리기', 'NNG'),
#   ('는', 'JX'),
#   ('이전', 'NNG'),
#   ('보다', 'JKM'),
#   ('더', 'MAG'),
#   ('빠르', 'VA'),
#   ('ㄹ', 'ETD'),
#   ('수', 'NNB'),
#   ('있', 'VV'),
#   ('다', 'ECS'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('루스', 'NNG'),
#   ('의', 'JKG'),
#   ('주행', 'NNG'),
#   ('속도', 'NNG'),
#   ('는', 'JX'),
#   ('시속', 'NNG'),
#   ('16', 'NR'),
#   ('40', 'NR'),
#   ('로', 'NNG'),
#   ('추정', 'NNG'),
#   ('되', 'XSV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('그', 'NP'),
#   ('보다', 'JKM'),
#   ('빠르', 'VA'),
#   ('면', 'ECE'),
#   ('뼈', 'NNG'),
#   ('가', 'JKS'),
#   ('부서지', 'VV'),
#   ('ㄴ다고', 'ECE'),
#   ('보', 'VXV'),
#   ('았', 'EPT'),
#   ('다', 'ECS'),
#   ('반면', 'NNG'),
#   ('네덜란드', 'NNG'),
#   ('연구진', 'NNG'),
#   ('은', 'JX'),
#   ('꼬리', 'NNG'),
#   ('가', 'JKS'),
#   ('충격', 'NNG'),
#   ('을', 'JKO'),
#   ('흡수', 'NNG'),
#   ('하', 'XSV'),
#   ('ㄴ다면', 'ECE'),
#   ('뼈', 'NNG'),
#   ('손상', 'NNG'),
#   ('없이', 'MAG'),
#   ('더', 'MAG'),
#   ('빨리', 'MAG'),
#   ('뛰', 'VV'),
#   ('ㄹ', 'ETD'),
#   ('수', 'NNB'),
#   ('있', 'VXV'),
#   ('다고', 'EFN')],
#  [('밝히', 'VV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('루스', 'NNG'),
#   ('의', 'JKG'),
#   ('꼬리', 'NNG'),
#   ('근육', 'NNG'),
#   ('을', 'JKO'),
#   ('토대', 'NNG'),
#   ('로', 'JKM'),
#   ('재구성', 'NNG'),
#   ('하', 'XSV'),
#   ('ㄴ', 'ETD'),
#   ('보행', 'NNG'),
#   ('모습', 'NNG'),
#   ('시속', 'NNG'),
#   ('4', 'NR'),
#   ('6', 'NR'),
#   ('km', 'OL'),
#   ('로', 'JKM'),
#   ('사람', 'NNG'),
#   ('보다', 'JKM'),
#   ('빠르', 'VA'),
#   ('지', 'ECD'),
#   ('않', 'VXV'),
#   ('았', 'EPT'),
#   ('더', 'EPT'),
#   ('ㄴ', 'ETD'),
#   ('것', 'NNB'),
#   ('으로', 'JKM'),
#   ('추정', 'NNG'),
#   ('되', 'XSV'),
#   ('ㄴ다', 'ECS'),
#   ('네덜란드', 'NNG'),
#   ('암', 'NNG'),
#   ('스테르', 'NNG'),
#   ('담', 'XSN'),
#   ('자유', 'NNG'),
#   ('대', 'NNG'),
#   ('1993', 'NR'),
#   ('년', 'NNG'),
#   ('쥬라기', 'NNG'),
#   ('공원', 'NNG'),
#   ('개봉', 'NNG'),
#   ('후', 'NNG'),
#   ('가장', 'MAG'),
#   ('크', 'VA'),
#   ('게', 'ECD'),
#   ('변', 'NNG'),
#   ('하', 'XSV'),
#   ('ㄴ', 'ETD'),
#   ('공룡', 'NNG'),
#   ('의', 'JKG'),
#   ('이미지', 'NNG'),
#   ('는', 'JX'),
#   ('털', 'NNG'),
#   ('이', 'VCP'),
#   ('다', 'ECS'),
#   ('하', 'VV'),
#   ('ㄴ', 'ETD'),
#   ('예', 'NNG'),
#   ('로', 'JKM'),
#   ('2012', 'NR'),
#   ('년', 'NNM'),
#   ('몸길이', 'NNG'),
#   ('9', 'NR'),
#   ('m', 'OL'),
#   ('의', 'JKG'),
#   ('대형', 'NNG'),
#   ('육식', 'NNG'),
#   ('공룡', 'NNG'),
#   ('유', 'NNG'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('누스', 'UN'),
#   ('가', 'JKS'),
#   ('털', 'NNG'),
#   ('로', 'JKM'),
#   ('덮이', 'VV'),
#   ('었', 'EPT'),
#   ('다는', 'ETD'),
#   ('연구', 'NNG'),
#   ('결과', 'NNG'),
#   ('가', 'JKS'),
#   ('나오', 'VV'),
#   ('았', 'EPT'),
#   ('다', 'ECS'),
#   ('그', 'MDT'),
#   ('뒤', 'NNG'),
#   ('에', 'JKM'),
#   ('나오', 'VV'),
#   ('ㄴ', 'ETD'),
#   ('사촌', 'NNG'),
#   ('격', 'NNB'),
#   ('이', 'VCP'),
#   ('ㄴ', 'ETD'),
#   ('티', 'NNG'),
#   ('라', 'NNG'),
#   ('노사', 'NNG'),
#   ('우', 'NNG'),
#   ('루스', 'NNG'),
#   ('도', 'JX'),
#   ('털', 'NNG'),
#   ('이', 'JKS'),
#   ('있', 'VV'),
#   ('었', 'EPT'),
#   ('을까', 'EFQ')],
#  [('2017', 'NR'),
#   ('년', 'NNM'),
#   ('미국', 'NNP'),
#   ('휴스턴', 'NNG'),
#   ('자연사', 'NNG'),
#   ('박물관', 'NNG'),
#   ('연구진', 'NNG'),
#   ('은', 'JX'),
#   ('유일한', 'NNG'),
#   ('티', 'NNG'),
#   ('라', 'NNG'),
#   ('노사', 'NNG'),
#   ('우', 'NNG'),
#   ('루스', 'NNG'),
#   ('의', 'JKG'),
#   ('피부', 'NNG'),
#   ('화석', 'NNG'),
#   ('을', 'JKO'),
#   ('조사', 'NNG'),
#   ('하', 'XSV'),
#   ('었', 'EPT'),
#   ('더니', 'ECD'),
#   ('목', 'NNG'),
#   ('과', 'JC'),
#   ('골반', 'NNG'),
#   ('꼬리', 'NNG'),
#   ('에', 'JKM'),
#   ('털', 'NNG'),
#   ('은', 'JX'),
#   ('없', 'VA'),
#   ('고', 'ECE'),
#   ('비늘', 'NNG'),
#   ('만', 'JX'),
#   ('있', 'VV'),
#   ('었', 'EPT'),
#   ('다고', 'EFN')],
#  [('밝히', 'VV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('연구진', 'NNG'),
#   ('은', 'JX'),
#   ('티', 'VV'),
#   ('라', 'ECD'),
#   ('노', 'NNG'),
#   ('사우', 'NNG'),
#   ('로', 'JKM'),
#   ('스', 'VV'),
#   ('는', 'ETD'),
#   ('열', 'NNG'),
#   ('을', 'JKO'),
#   ('잘', 'MAG'),
#   ('보존', 'NNG'),
#   ('하', 'XSV'),
#   ('ㄹ', 'ETD'),
#   ('수', 'NNB'),
#   ('있', 'VV'),
#   ('어', 'ECD'),
#   ('이전', 'NNG'),
#   ('에', 'JKM'),
#   ('단열', 'NNG'),
#   ('역할', 'NNG'),
#   ('을', 'JKO'),
#   ('하', 'VV'),
#   ('더', 'EPT'),
#   ('ㄴ', 'ETD'),
#   ('털', 'NNG'),
#   ('이', 'JKS'),
#   ('사라지', 'VV'),
#   ('었', 'EPT'),
#   ('다', 'EFN'),
#   ('고', 'JKQ'),
#   ('추정', 'NNG'),
#   ('하', 'XSV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('만약', 'NNG'),
#   ('털이', 'NNG'),
#   ('있', 'VA'),
#   ('다면', 'ECE'),
#   ('등에', 'NNG'),
#   ('만', 'JX'),
#   ('일부', 'NNG'),
#   ('남', 'VV'),
#   ('았', 'EPT'),
#   ('을', 'ETD'),
#   ('것', 'NNB'),
#   ('이', 'VCP'),
#   ('라고', 'ECD'),
#   ('주장', 'NNG'),
#   ('하', 'XSV'),
#   ('었', 'EPT'),
#   ('다', 'ECS'),
#   ('이영', 'MAG'),
#   ('와', 'VV'),
#   ('ㄴ', 'ETD'),
#   ('과학', 'NNG'),
#   ('전문', 'NNG'),
#   ('기자', 'NNG'),
#   ('ywlee', 'OL'),
#   ('chosun', 'OL'),
#   ('com', 'OL'),
#   ('조선', 'NNG'),
#   ('일보', 'NNG'),
#   ('가', 'JKS'),
#   ('뽑', 'VV'),
#   ('은', 'ETD'),
#   ('뉴스', 'NNG'),
#   ('확인', 'NNG'),
#   ('하', 'XSV'),
#   ('어', 'ECS'),
#   ('보세', 'NNG'),
#   ('요', 'JX'),
#   ('최고', 'NNG'),
#   ('기자', 'NNG'),
#   ('들', 'XSN'),
#   ('의', 'JKG'),
#   ('뉴스', 'NNG'),
#   ('레터', 'NNG'),
#   ('받', 'VV'),
#   ('아', 'ECD'),
#   ('보', 'VV'),
#   ('세요', 'EFN')],
#  [('1', 'NR'),
#   ('등', 'NNM'),
#   ('신문', 'NNG'),
#   ('조선', 'NNG'),
#   ('일보', 'NNG'),
#   ('앱으', 'UN'),
#   ('로', 'JKM'),
#   ('편하', 'VA'),
#   ('게', 'ECD'),
#   ('보', 'VV'),
#   ('세요', 'EFN')]]

# %%
def makeLstSent(argLstPosSent, argOne=True):
    
    lstStop = ["E", "J"]
    lstStrSent = []
    for oneSent in argLstPosSent:
        strOneSent = ""
        for tp in oneSent:
            lstIsStop = [x in tp[1] for x in lstStop]
            if not any(lstIsStop):
                strOneSent += (" "+tp[0])
        lstStrSent.append(strOneSent)
    if argOne:
        lstStrSent = [" ".join(lstStrSent)]
    return(lstStrSent)
lstSent = makeLstSent(lstPosSent, True)
lstSent
# Out:
# [' flash 오류 우회 하 위하 함수 추가 function _ flash _ removecallback 평균 보행 속 시속 4 6 km 빨리 걷 사람 느리 속도 영화 차 따르 잡 수 없 멸종 전 약 25 억 마리 서식 하 곳 무리 화석 발견 되 집단 사냥 하 것 추정 되 쥐라기 후기 약 250 만 년 동안 지구 지배 하 티 라 노사 우 루스 온전히 발굴 되 화석 32 마리 없 아직 밝혀지 않 부분 많  uc 버클리 공룡 계의 스타 단연 영화 쥬라기 공원 의 로고 나오 티 라 노사 우 루스 이 몸길이 12 m 최대 9 톤 가까이 갈 몸무게 모든 동물 공포 몰아넣 하지만 명성 비하 아직 모르 점 많 티 노 사우 루스 얼마나 빠르  혼자 다니 고독 하 사냥꾼 이  집안 총동원 하  최근 과학자 들 그동안 미스터리 남 있 티 라 노사 우 루스 진면목 잇따르 밝혀내 지구 등장 하 티 놀 25 억 마리 티 노 사우 스 쥐라기 후기 6800 만 년 6550 만 년 전 살 그 사이 얼마나 많 공룡 살  캘리포니아 대 uc 새 타 바 버라 존 다 무스 교수 동물 개체 밀도 신체 크기 연관짓 즉 같 면적 쥐 코끼리 수가 적 이른바 다 무스 법 칙 이  uc 버클리 찰스 마 셜 교수 지나 16 일 사이언스 다 무스 법칙 근거 티 노 사우 루스 개체 밀도 100 당 약 1 마리 계산 하 캘리포니아 주 한 면적 3800 마리 쯤 사 셈 이 오늘날 북미 대륙 전체 동시 살 개체 수 약 2 만 마리 되 또 티 노 사우 루스 한 세대 19 년 이 멸종 이르 250 만 년 동안 12 만 7000 세대 걸치 총 25 억 마리 살  보 수 있 그러 화석 발굴 되 티 라 노사 우 루스 32 마리 그치 그만큼 대형 육식 공룡 화석 남기 어렵 말 이 공룡 제왕 티 라 노사 우 루스 미스터리 2014 년 미국 토지 관리국 고생물 학자 이 앨 런 티투스 박사 유타주 남부 티 노 사우 루스 무리 화석 발굴 하 어르 공룡 1 마리 젊 공룡 1 마리 어리 공룡 3 마리 이 티투스 박사 아칸소 대의 셀 리 수 아 레 즈 교수 공동 연구진 지나 19 일 국제 학술지 피어 제이 peerj 연대 측정 통하 공룡 가족 동시 홍수 화석 되 이 티 노 사우 루스 오늘날 늑대 가족 함께 살 사냥 같이 하 증거 되 이 밝히 앞서 캐나다 미국 몬태나 주 티 노 사우 루스 무리 화석 발굴 되 적이 있 하지만 공룡 두뇌 집단 사냥 하 만큼 발달 하  보 어렵 비판 있다 피부 덮 것 털 이 비늘 이 영화 보 티 노 사우 루스 사람 들 타 차 따라잡 장면 나오 네덜란드 암 스테르 담 자유 대 연구진 지나 21 일 왕립 학회 오픈 사이언스 티 노 사우 루스 보행 속도 시속 5 가 채 되 않  밝히 사람 빨리 걷 도망가 수 있 말 이 과학자 들 공룡 몸무게 엉덩이 높이 발자국 화석 토대 티 노 사우 루스 보행 속도 시속 7 2 10 8 로 추산 하 하지만 네덜란드 연구진 몸무게 키 꼬리 주목 하 공룡 꼬리 위아래 흔들리 균형 잡 주 몸 앞 가 하 주 것 이 연구진 네덜란드 있 티 라 노사 우 루스 화석 꼬리 토대 공룡 컴퓨터 모델 만들 꼬리 근육 탄성 흔들리 주기 감안 하면 평균 보행 속도 시속 4 6 로 나오 달리기 이전 더 빠르 수 있 티 노 사우 루스 주행 속도 시속 16 40 로 추정 되 그 빠르 뼈 부서지 보 반면 네덜란드 연구진 꼬리 충격 흡수 하 뼈 손상 없이 더 빨리 뛰 수 있  밝히 티 노 사우 루스 꼬리 근육 토대 재구성 하 보행 모습 시속 4 6 km 사람 빠르 않 것 추정 되 네덜란드 암 스테르 담 자유 대 1993 년 쥬라기 공원 개봉 후 가장 크 변 하 공룡 이미지 털 이 하 예 2012 년 몸길이 9 m 대형 육식 공룡 유 티 누스 털 덮이 연구 결과 나오 그 뒤 나오 사촌 격 이 티 라 노사 우 루스 털 있  2017 년 미국 휴스턴 자연사 박물관 연구진 유일한 티 라 노사 우 루스 피부 화석 조사 하 목 골반 꼬리 털 없 비늘 있  밝히 연구진 티 노 사우 스 열 잘 보존 하 수 있 이전 단열 역할 하 털 사라지 추정 하 만약 털이 있 등에 일부 남 것 이 주장 하 이영 와 과학 전문 기자 ywlee chosun com 조선 일보 뽑 뉴스 확인 하 보세 최고 기자 들 뉴스 레터 받 보  1 등 신문 조선 일보 앱으 편하 보']

# %%
def makeNGram(argLstSent, argNum = 3):
    vectMy = CountVectorizer(ngram_range=(argNum, argNum), analyzer="word")
    lstNGram = vectMy.fit(argLstSent).get_feature_names()
    # ar2NGramCnt = vectMy.transform(argLstSent).toarray()        # 결과는 array of array.
    # lstNGramCnt = list(ar2NGramCnt[0])                          # 단순한 리스트로 변환.
    return(lstNGram)

lstNGram = makeNGram(lstSent)
lstNGram
# Out:
# ['10 추산 하지만',
#  '100 마리 계산',
#  '12 7000 세대',
#  '12 최대 가까이',
#  '16 40 추정',
#  '16 사이언스 무스',
#  '19 국제 학술지',
#  '19 멸종 이르',
#  '1993 쥬라기 공원',
#  '2012 몸길이 대형',
#  '2014 미국 토지',
#  '2017 미국 휴스턴',
#  '21 왕립 학회',
#  '25 마리 그러',
#  '25 마리 사우',
#  '25 마리 서식',
#  '250 동안 12',
#  '250 동안 지구',
#  '32 마리 그치',
#  '32 마리 아직',
#  '3800 마리 오늘날',
#  '40 추정 빠르',
#  '6550 사이 얼마나',
#  '6800 6550 사이',
#  '7000 세대 걸치',
#  'chosun com 조선',
#  'com 조선 일보',
#  'flash removecallback 평균',
#  'flash 오류 우회',
#  'function flash removecallback',
#  'km 빨리 사람',
#  'km 사람 빠르',
#  'peerj 연대 측정',
#  'removecallback 평균 보행',
#  'uc 버라 무스',
#  'uc 버클리 공룡',
#  'uc 버클리 찰스',
#  'ywlee chosun com',
#  '가까이 몸무게 모든',
#  '가장 공룡 이미지',
#  '가족 동시 홍수',
#  '가족 함께 사냥',
#  '감안 하면 평균',
#  '같이 증거 밝히',
#  '개봉 가장 공룡',
#  '개체 마리 사우',
#  '개체 밀도 100',
#  '개체 밀도 신체',
#  '걸치 25 마리',
#  '결과 나오 나오',
#  '계산 캘리포니아 면적',
#  '계의 스타 단연',
#  '고독 사냥꾼 집안',
#  '고생물 학자 티투스',
#  '골반 꼬리 비늘',
#  '공동 연구진 지나',
#  '공룡 가족 동시',
#  '공룡 계의 스타',
#  '공룡 꼬리 위아래',
#  '공룡 누스 덮이',
#  '공룡 두뇌 집단',
#  '공룡 마리 공룡',
#  '공룡 마리 어리',
#  '공룡 마리 티투스',
#  '공룡 몸무게 엉덩이',
#  '공룡 이미지 2012',
#  '공룡 제왕 노사',
#  '공룡 캘리포니아 uc',
#  '공룡 컴퓨터 모델',
#  '공룡 화석 남기',
#  '공원 개봉 가장',
#  '공원 로고 나오',
#  '공포 몰아넣 하지만',
#  '과학 전문 기자',
#  '과학자 공룡 몸무게',
#  '과학자 그동안 미스터리',
#  '관리국 고생물 학자',
#  '교수 공동 연구진',
#  '교수 동물 개체',
#  '교수 지나 16',
#  '국제 학술지 피어',
#  '균형 연구진 네덜란드',
#  '그동안 미스터리 노사',
#  '그러 화석 발굴',
#  '그만큼 대형 육식',
#  '그치 그만큼 대형',
#  '근거 사우 루스',
#  '근육 탄성 흔들리',
#  '근육 토대 재구성',
#  '기자 ywlee chosun',
#  '기자 뉴스 레터',
#  '꼬리 근육 탄성',
#  '꼬리 근육 토대',
#  '꼬리 비늘 밝히',
#  '꼬리 위아래 흔들리',
#  '꼬리 주목 공룡',
#  '꼬리 충격 흡수',
#  '꼬리 토대 공룡',
#  '나오 나오 사촌',
#  '나오 네덜란드 스테르',
#  '나오 노사 루스',
#  '나오 달리기 이전',
#  '나오 사촌 노사',
#  '남기 어렵 공룡',
#  '남부 사우 루스',
#  '네덜란드 노사 루스',
#  '네덜란드 스테르 자유',
#  '네덜란드 연구진 꼬리',
#  '네덜란드 연구진 몸무게',
#  '노사 루스 2017',
#  '노사 루스 32',
#  '노사 루스 몸길이',
#  '노사 루스 미스터리',
#  '노사 루스 온전히',
#  '노사 루스 진면목',
#  '노사 루스 피부',
#  '노사 루스 화석',
#  '높이 발자국 화석',
#  '누스 덮이 연구',
#  '뉴스 레터 신문',
#  '뉴스 확인 보세',
#  '느리 속도 영화',
#  '늑대 가족 함께',
#  '다니 고독 사냥꾼',
#  '단연 영화 쥬라기',
#  '단열 역할 사라지',
#  '달리기 이전 빠르',
#  '대륙 전체 동시',
#  '대의 교수 공동',
#  '대형 육식 공룡',
#  '덮이 연구 결과',
#  '도망가 과학자 공룡',
#  '동물 개체 밀도',
#  '동물 공포 몰아넣',
#  '동시 개체 마리',
#  '동시 홍수 화석',
#  '동안 12 7000',
#  '동안 지구 지배',
#  '두뇌 집단 사냥',
#  '등에 일부 주장',
#  '등장 25 마리',
#  '따라잡 장면 나오',
#  '따르 멸종 25',
#  '레터 신문 조선',
#  '로고 나오 노사',
#  '루스 2017 미국',
#  '루스 32 마리',
#  '루스 개체 밀도',
#  '루스 꼬리 근육',
#  '루스 몸길이 12',
#  '루스 무리 화석',
#  '루스 미스터리 2014',
#  '루스 보행 속도',
#  '루스 사람 따라잡',
#  '루스 세대 19',
#  '루스 얼마나 빠르',
#  '루스 오늘날 늑대',
#  '루스 온전히 발굴',
#  '루스 주행 속도',
#  '루스 진면목 잇따르',
#  '루스 피부 화석',
#  '루스 화석 꼬리',
#  '마리 계산 캘리포니아',
#  '마리 공룡 마리',
#  '마리 그러 화석',
#  '마리 그치 그만큼',
#  '마리 사우 루스',
#  '마리 사우 쥐라기',
#  '마리 서식 무리',
#  '마리 아직 밝혀지',
#  '마리 어리 공룡',
#  '마리 오늘날 북미',
#  '마리 티투스 박사',
#  '만들 꼬리 근육',
#  '만약 털이 등에',
#  '만큼 발달 어렵',
#  '면적 3800 마리',
#  '면적 코끼리 수가',
#  '멸종 25 마리',
#  '멸종 이르 250',
#  '명성 비하 아직',
#  '모델 만들 꼬리',
#  '모든 동물 공포',
#  '모르 사우 루스',
#  '모습 시속 km',
#  '몬태나 사우 루스',
#  '몰아넣 하지만 명성',
#  '몸길이 12 최대',
#  '몸길이 대형 육식',
#  '몸무게 꼬리 주목',
#  '몸무게 모든 동물',
#  '몸무게 엉덩이 높이',
#  '무리 화석 발견',
#  '무리 화석 발굴',
#  '무스 uc 버클리',
#  '무스 교수 동물',
#  '무스 법칙 근거',
#  '미국 몬태나 사우',
#  '미국 토지 관리국',
#  '미국 휴스턴 자연사',
#  '미스터리 2014 미국',
#  '미스터리 노사 루스',
#  '밀도 100 마리',
#  '밀도 신체 크기',
#  '박물관 연구진 유일한',
#  '박사 아칸소 대의',
#  '박사 유타주 남부',
#  '반면 네덜란드 연구진',
#  '발견 집단 사냥',
#  '발굴 노사 루스',
#  '발굴 어르 공룡',
#  '발굴 적이 하지만',
#  '발굴 화석 32',
#  '발달 어렵 비판',
#  '발자국 화석 토대',
#  '밝혀내 지구 등장',
#  '밝혀지 부분 uc',
#  '밝히 사람 빨리',
#  '밝히 사우 루스',
#  '밝히 앞서 캐나다',
#  '밝히 연구진 사우',
#  '버라 무스 교수',
#  '버클리 공룡 계의',
#  '버클리 찰스 교수',
#  '법칙 근거 사우',
#  '보세 최고 기자',
#  '보존 이전 단열',
#  '보행 모습 시속',
#  '보행 속도 시속',
#  '보행 시속 km',
#  '부분 uc 버클리',
#  '부서지 반면 네덜란드',
#  '북미 대륙 전체',
#  '비늘 밝히 연구진',
#  '비늘 영화 사우',
#  '비판 있다 피부',
#  '비하 아직 모르',
#  '빠르 부서지 반면',
#  '빠르 사우 루스',
#  '빠르 추정 네덜란드',
#  '빠르 혼자 다니',
#  '빨리 도망가 과학자',
#  '빨리 밝히 사우',
#  '빨리 사람 느리',
#  '사냥 같이 증거',
#  '사냥 만큼 발달',
#  '사냥 추정 쥐라기',
#  '사냥꾼 집안 총동원',
#  '사라지 추정 만약',
#  '사람 느리 속도',
#  '사람 따라잡 장면',
#  '사람 빠르 추정',
#  '사람 빨리 도망가',
#  '사우 루스 개체',
#  '사우 루스 꼬리',
#  '사우 루스 무리',
#  '사우 루스 보행',
#  '사우 루스 사람',
#  '사우 루스 세대',
#  '사우 루스 얼마나',
#  '사우 루스 오늘날',
#  '사우 루스 주행',
#  '사우 보존 이전',
#  '사우 쥐라기 후기',
#  '사이 얼마나 공룡',
#  '사이언스 무스 법칙',
#  '사이언스 사우 루스',
#  '사촌 노사 루스',
#  '서식 무리 화석',
#  '세대 19 멸종',
#  '세대 걸치 25',
#  '속도 시속 10',
#  '속도 시속 16',
#  '속도 시속 나오',
#  '속도 시속 밝히',
#  '속도 영화 따르',
#  '손상 없이 빨리',
#  '수가 이른바 무스',
#  '스타 단연 영화',
#  '스테르 자유 1993',
#  '스테르 자유 연구진',
#  '시속 10 추산',
#  '시속 16 40',
#  '시속 km 빨리',
#  '시속 km 사람',
#  '시속 나오 달리기',
#  '시속 밝히 사람',
#  '신문 조선 일보',
#  '신체 크기 연관짓',
#  '아직 모르 사우',
#  '아직 밝혀지 부분',
#  '아칸소 대의 교수',
#  '앞서 캐나다 미국',
#  '어렵 공룡 제왕',
#  '어렵 비판 있다',
#  '어르 공룡 마리',
#  '어리 공룡 마리',
#  '얼마나 공룡 캘리포니아',
#  '얼마나 빠르 혼자',
#  '없이 빨리 밝히',
#  '엉덩이 높이 발자국',
#  '역할 사라지 추정',
#  '연관짓 면적 코끼리',
#  '연구 결과 나오',
#  '연구진 꼬리 충격',
#  '연구진 네덜란드 노사',
#  '연구진 몸무게 꼬리',
#  '연구진 사우 보존',
#  '연구진 유일한 노사',
#  '연구진 지나 19',
#  '연구진 지나 21',
#  '연대 측정 통하',
#  '영화 따르 멸종',
#  '영화 사우 루스',
#  '영화 쥬라기 공원',
#  '오늘날 늑대 가족',
#  '오늘날 북미 대륙',
#  '오류 우회 위하',
#  '오픈 사이언스 사우',
#  '온전히 발굴 화석',
#  '왕립 학회 오픈',
#  '우회 위하 함수',
#  '위아래 흔들리 균형',
#  '위하 함수 추가',
#  '유일한 노사 루스',
#  '유타주 남부 사우',
#  '육식 공룡 누스',
#  '육식 공룡 화석',
#  '이르 250 동안',
#  '이른바 무스 uc',
#  '이미지 2012 몸길이',
#  '이영 과학 전문',
#  '이전 단열 역할',
#  '이전 빠르 사우',
#  '일보 뉴스 확인',
#  '일보 앱으 편하',
#  '일부 주장 이영',
#  '잇따르 밝혀내 지구',
#  '있다 피부 비늘',
#  '자연사 박물관 연구진',
#  '자유 1993 쥬라기',
#  '자유 연구진 지나',
#  '장면 나오 네덜란드',
#  '재구성 보행 모습',
#  '적이 하지만 공룡',
#  '전문 기자 ywlee',
#  '전체 동시 개체',
#  '제왕 노사 루스',
#  '제이 peerj 연대',
#  '조사 골반 꼬리',
#  '조선 일보 뉴스',
#  '조선 일보 앱으',
#  '주기 감안 하면',
#  '주목 공룡 꼬리',
#  '주장 이영 과학',
#  '주행 속도 시속',
#  '쥐라기 후기 250',
#  '쥐라기 후기 6800',
#  '쥬라기 공원 개봉',
#  '쥬라기 공원 로고',
#  '증거 밝히 앞서',
#  '지구 등장 25',
#  '지구 지배 노사',
#  '지나 16 사이언스',
#  '지나 19 국제',
#  '지나 21 왕립',
#  '지배 노사 루스',
#  '진면목 잇따르 밝혀내',
#  '집단 사냥 만큼',
#  '집단 사냥 추정',
#  '집안 총동원 최근',
#  '찰스 교수 지나',
#  '총동원 최근 과학자',
#  '최고 기자 뉴스',
#  '최근 과학자 그동안',
#  '최대 가까이 몸무게',
#  '추가 function flash',
#  '추산 하지만 네덜란드',
#  '추정 네덜란드 스테르',
#  '추정 만약 털이',
#  '추정 빠르 부서지',
#  '추정 쥐라기 후기',
#  '충격 흡수 손상',
#  '측정 통하 공룡',
#  '캐나다 미국 몬태나',
#  '캘리포니아 uc 버라',
#  '캘리포니아 면적 3800',
#  '컴퓨터 모델 만들',
#  '코끼리 수가 이른바',
#  '크기 연관짓 면적',
#  '탄성 흔들리 주기',
#  '털이 등에 일부',
#  '토대 공룡 컴퓨터',
#  '토대 사우 루스',
#  '토대 재구성 보행',
#  '토지 관리국 고생물',
#  '통하 공룡 가족',
#  '티투스 박사 아칸소',
#  '티투스 박사 유타주',
#  '평균 보행 속도',
#  '평균 보행 시속',
#  '피부 비늘 영화',
#  '피부 화석 조사',
#  '피어 제이 peerj',
#  '하면 평균 보행',
#  '하지만 공룡 두뇌',
#  '하지만 네덜란드 연구진',
#  '하지만 명성 비하',
#  '학술지 피어 제이',
#  '학자 티투스 박사',
#  '학회 오픈 사이언스',
#  '함께 사냥 같이',
#  '함수 추가 function',
#  '혼자 다니 고독',
#  '홍수 화석 사우',
#  '화석 32 마리',
#  '화석 꼬리 토대',
#  '화석 남기 어렵',
#  '화석 발견 집단',
#  '화석 발굴 노사',
#  '화석 발굴 어르',
#  '화석 발굴 적이',
#  '화석 사우 루스',
#  '화석 조사 골반',
#  '화석 토대 사우',
#  '확인 보세 최고',
#  '후기 250 동안',
#  '후기 6800 6550',
#  '휴스턴 자연사 박물관',
#  '흔들리 균형 연구진',
#  '흔들리 주기 감안',
#  '흡수 손상 없이']

# %%
def makeBaseDic(argLstNGram, argNum=3):
    dicBase = {}
    for x in argLstNGram:
        lstWord = nltk.word_tokenize(x)
        preGram = ' '.join(lstWord[0:argNum-1])
        pstGram = lstWord[-1]
        
        if preGram not in dicBase.keys():
            dicBase[preGram] = [pstGram]
        else:
            dicBase[preGram] += [pstGram]
    return(dicBase)
dicBase = makeBaseDic(lstNGram)
dicBase
# Out:
# {'10 추산': ['하지만'],
#  '100 마리': ['계산'],
#  '12 7000': ['세대'],
#  '12 최대': ['가까이'],
#  '16 40': ['추정'],
#  '16 사이언스': ['무스'],
#  '19 국제': ['학술지'],
#  '19 멸종': ['이르'],
#  '1993 쥬라기': ['공원'],
#  '2012 몸길이': ['대형'],
#  '2014 미국': ['토지'],
#  '2017 미국': ['휴스턴'],
#  '21 왕립': ['학회'],
#  '25 마리': ['그러', '사우', '서식'],
#  '250 동안': ['12', '지구'],
#  '32 마리': ['그치', '아직'],
#  '3800 마리': ['오늘날'],
#  '40 추정': ['빠르'],
#  '6550 사이': ['얼마나'],
#  '6800 6550': ['사이'],
#  '7000 세대': ['걸치'],
#  'chosun com': ['조선'],
#  'com 조선': ['일보'],
#  'flash removecallback': ['평균'],
#  'flash 오류': ['우회'],
#  'function flash': ['removecallback'],
#  'km 빨리': ['사람'],
#  'km 사람': ['빠르'],
#  'peerj 연대': ['측정'],
#  'removecallback 평균': ['보행'],
#  'uc 버라': ['무스'],
#  'uc 버클리': ['공룡', '찰스'],
#  'ywlee chosun': ['com'],
#  '가까이 몸무게': ['모든'],
#  '가장 공룡': ['이미지'],
#  '가족 동시': ['홍수'],
#  '가족 함께': ['사냥'],
#  '감안 하면': ['평균'],
#  '같이 증거': ['밝히'],
#  '개봉 가장': ['공룡'],
#  '개체 마리': ['사우'],
#  '개체 밀도': ['100', '신체'],
#  '걸치 25': ['마리'],
#  '결과 나오': ['나오'],
#  '계산 캘리포니아': ['면적'],
#  '계의 스타': ['단연'],
#  '고독 사냥꾼': ['집안'],
#  '고생물 학자': ['티투스'],
#  '골반 꼬리': ['비늘'],
#  '공동 연구진': ['지나'],
#  '공룡 가족': ['동시'],
#  '공룡 계의': ['스타'],
#  '공룡 꼬리': ['위아래'],
#  '공룡 누스': ['덮이'],
#  '공룡 두뇌': ['집단'],
#  '공룡 마리': ['공룡', '어리', '티투스'],
#  '공룡 몸무게': ['엉덩이'],
#  '공룡 이미지': ['2012'],
#  '공룡 제왕': ['노사'],
#  '공룡 캘리포니아': ['uc'],
#  '공룡 컴퓨터': ['모델'],
#  '공룡 화석': ['남기'],
#  '공원 개봉': ['가장'],
#  '공원 로고': ['나오'],
#  '공포 몰아넣': ['하지만'],
#  '과학 전문': ['기자'],
#  '과학자 공룡': ['몸무게'],
#  '과학자 그동안': ['미스터리'],
#  '관리국 고생물': ['학자'],
#  '교수 공동': ['연구진'],
#  '교수 동물': ['개체'],
#  '교수 지나': ['16'],
#  '국제 학술지': ['피어'],
#  '균형 연구진': ['네덜란드'],
#  '그동안 미스터리': ['노사'],
#  '그러 화석': ['발굴'],
#  '그만큼 대형': ['육식'],
#  '그치 그만큼': ['대형'],
#  '근거 사우': ['루스'],
#  '근육 탄성': ['흔들리'],
#  '근육 토대': ['재구성'],
#  '기자 ywlee': ['chosun'],
#  '기자 뉴스': ['레터'],
#  '꼬리 근육': ['탄성', '토대'],
#  '꼬리 비늘': ['밝히'],
#  '꼬리 위아래': ['흔들리'],
#  '꼬리 주목': ['공룡'],
#  '꼬리 충격': ['흡수'],
#  '꼬리 토대': ['공룡'],
#  '나오 나오': ['사촌'],
#  '나오 네덜란드': ['스테르'],
#  '나오 노사': ['루스'],
#  '나오 달리기': ['이전'],
#  '나오 사촌': ['노사'],
#  '남기 어렵': ['공룡'],
#  '남부 사우': ['루스'],
#  '네덜란드 노사': ['루스'],
#  '네덜란드 스테르': ['자유'],
#  '네덜란드 연구진': ['꼬리', '몸무게'],
#  '노사 루스': ['2017', '32', '몸길이', '미스터리', '온전히', '진면목', '피부', '화석'],
#  '높이 발자국': ['화석'],
#  '누스 덮이': ['연구'],
#  '뉴스 레터': ['신문'],
#  '뉴스 확인': ['보세'],
#  '느리 속도': ['영화'],
#  '늑대 가족': ['함께'],
#  '다니 고독': ['사냥꾼'],
#  '단연 영화': ['쥬라기'],
#  '단열 역할': ['사라지'],
#  '달리기 이전': ['빠르'],
#  '대륙 전체': ['동시'],
#  '대의 교수': ['공동'],
#  '대형 육식': ['공룡'],
#  '덮이 연구': ['결과'],
#  '도망가 과학자': ['공룡'],
#  '동물 개체': ['밀도'],
#  '동물 공포': ['몰아넣'],
#  '동시 개체': ['마리'],
#  '동시 홍수': ['화석'],
#  '동안 12': ['7000'],
#  '동안 지구': ['지배'],
#  '두뇌 집단': ['사냥'],
#  '등에 일부': ['주장'],
#  '등장 25': ['마리'],
#  '따라잡 장면': ['나오'],
#  '따르 멸종': ['25'],
#  '레터 신문': ['조선'],
#  '로고 나오': ['노사'],
#  '루스 2017': ['미국'],
#  '루스 32': ['마리'],
#  '루스 개체': ['밀도'],
#  '루스 꼬리': ['근육'],
#  '루스 몸길이': ['12'],
#  '루스 무리': ['화석'],
#  '루스 미스터리': ['2014'],
#  '루스 보행': ['속도'],
#  '루스 사람': ['따라잡'],
#  '루스 세대': ['19'],
#  '루스 얼마나': ['빠르'],
#  '루스 오늘날': ['늑대'],
#  '루스 온전히': ['발굴'],
#  '루스 주행': ['속도'],
#  '루스 진면목': ['잇따르'],
#  '루스 피부': ['화석'],
#  '루스 화석': ['꼬리'],
#  '마리 계산': ['캘리포니아'],
#  '마리 공룡': ['마리'],
#  '마리 그러': ['화석'],
#  '마리 그치': ['그만큼'],
#  '마리 사우': ['루스', '쥐라기'],
#  '마리 서식': ['무리'],
#  '마리 아직': ['밝혀지'],
#  '마리 어리': ['공룡'],
#  '마리 오늘날': ['북미'],
#  '마리 티투스': ['박사'],
#  '만들 꼬리': ['근육'],
#  '만약 털이': ['등에'],
#  '만큼 발달': ['어렵'],
#  '면적 3800': ['마리'],
#  '면적 코끼리': ['수가'],
#  '멸종 25': ['마리'],
#  '멸종 이르': ['250'],
#  '명성 비하': ['아직'],
#  '모델 만들': ['꼬리'],
#  '모든 동물': ['공포'],
#  '모르 사우': ['루스'],
#  '모습 시속': ['km'],
#  '몬태나 사우': ['루스'],
#  '몰아넣 하지만': ['명성'],
#  '몸길이 12': ['최대'],
#  '몸길이 대형': ['육식'],
#  '몸무게 꼬리': ['주목'],
#  '몸무게 모든': ['동물'],
#  '몸무게 엉덩이': ['높이'],
#  '무리 화석': ['발견', '발굴'],
#  '무스 uc': ['버클리'],
#  '무스 교수': ['동물'],
#  '무스 법칙': ['근거'],
#  '미국 몬태나': ['사우'],
#  '미국 토지': ['관리국'],
#  '미국 휴스턴': ['자연사'],
#  '미스터리 2014': ['미국'],
#  '미스터리 노사': ['루스'],
#  '밀도 100': ['마리'],
#  '밀도 신체': ['크기'],
#  '박물관 연구진': ['유일한'],
#  '박사 아칸소': ['대의'],
#  '박사 유타주': ['남부'],
#  '반면 네덜란드': ['연구진'],
#  '발견 집단': ['사냥'],
#  '발굴 노사': ['루스'],
#  '발굴 어르': ['공룡'],
#  '발굴 적이': ['하지만'],
#  '발굴 화석': ['32'],
#  '발달 어렵': ['비판'],
#  '발자국 화석': ['토대'],
#  '밝혀내 지구': ['등장'],
#  '밝혀지 부분': ['uc'],
#  '밝히 사람': ['빨리'],
#  '밝히 사우': ['루스'],
#  '밝히 앞서': ['캐나다'],
#  '밝히 연구진': ['사우'],
#  '버라 무스': ['교수'],
#  '버클리 공룡': ['계의'],
#  '버클리 찰스': ['교수'],
#  '법칙 근거': ['사우'],
#  '보세 최고': ['기자'],
#  '보존 이전': ['단열'],
#  '보행 모습': ['시속'],
#  '보행 속도': ['시속'],
#  '보행 시속': ['km'],
#  '부분 uc': ['버클리'],
#  '부서지 반면': ['네덜란드'],
#  '북미 대륙': ['전체'],
#  '비늘 밝히': ['연구진'],
#  '비늘 영화': ['사우'],
#  '비판 있다': ['피부'],
#  '비하 아직': ['모르'],
#  '빠르 부서지': ['반면'],
#  '빠르 사우': ['루스'],
#  '빠르 추정': ['네덜란드'],
#  '빠르 혼자': ['다니'],
#  '빨리 도망가': ['과학자'],
#  '빨리 밝히': ['사우'],
#  '빨리 사람': ['느리'],
#  '사냥 같이': ['증거'],
#  '사냥 만큼': ['발달'],
#  '사냥 추정': ['쥐라기'],
#  '사냥꾼 집안': ['총동원'],
#  '사라지 추정': ['만약'],
#  '사람 느리': ['속도'],
#  '사람 따라잡': ['장면'],
#  '사람 빠르': ['추정'],
#  '사람 빨리': ['도망가'],
#  '사우 루스': ['개체', '꼬리', '무리', '보행', '사람', '세대', '얼마나', '오늘날', '주행'],
#  '사우 보존': ['이전'],
#  '사우 쥐라기': ['후기'],
#  '사이 얼마나': ['공룡'],
#  '사이언스 무스': ['법칙'],
#  '사이언스 사우': ['루스'],
#  '사촌 노사': ['루스'],
#  '서식 무리': ['화석'],
#  '세대 19': ['멸종'],
#  '세대 걸치': ['25'],
#  '속도 시속': ['10', '16', '나오', '밝히'],
#  '속도 영화': ['따르'],
#  '손상 없이': ['빨리'],
#  '수가 이른바': ['무스'],
#  '스타 단연': ['영화'],
#  '스테르 자유': ['1993', '연구진'],
#  '시속 10': ['추산'],
#  '시속 16': ['40'],
#  '시속 km': ['빨리', '사람'],
#  '시속 나오': ['달리기'],
#  '시속 밝히': ['사람'],
#  '신문 조선': ['일보'],
#  '신체 크기': ['연관짓'],
#  '아직 모르': ['사우'],
#  '아직 밝혀지': ['부분'],
#  '아칸소 대의': ['교수'],
#  '앞서 캐나다': ['미국'],
#  '어렵 공룡': ['제왕'],
#  '어렵 비판': ['있다'],
#  '어르 공룡': ['마리'],
#  '어리 공룡': ['마리'],
#  '얼마나 공룡': ['캘리포니아'],
#  '얼마나 빠르': ['혼자'],
#  '없이 빨리': ['밝히'],
#  '엉덩이 높이': ['발자국'],
#  '역할 사라지': ['추정'],
#  '연관짓 면적': ['코끼리'],
#  '연구 결과': ['나오'],
#  '연구진 꼬리': ['충격'],
#  '연구진 네덜란드': ['노사'],
#  '연구진 몸무게': ['꼬리'],
#  '연구진 사우': ['보존'],
#  '연구진 유일한': ['노사'],
#  '연구진 지나': ['19', '21'],
#  '연대 측정': ['통하'],
#  '영화 따르': ['멸종'],
#  '영화 사우': ['루스'],
#  '영화 쥬라기': ['공원'],
#  '오늘날 늑대': ['가족'],
#  '오늘날 북미': ['대륙'],
#  '오류 우회': ['위하'],
#  '오픈 사이언스': ['사우'],
#  '온전히 발굴': ['화석'],
#  '왕립 학회': ['오픈'],
#  '우회 위하': ['함수'],
#  '위아래 흔들리': ['균형'],
#  '위하 함수': ['추가'],
#  '유일한 노사': ['루스'],
#  '유타주 남부': ['사우'],
#  '육식 공룡': ['누스', '화석'],
#  '이르 250': ['동안'],
#  '이른바 무스': ['uc'],
#  '이미지 2012': ['몸길이'],
#  '이영 과학': ['전문'],
#  '이전 단열': ['역할'],
#  '이전 빠르': ['사우'],
#  '일보 뉴스': ['확인'],
#  '일보 앱으': ['편하'],
#  '일부 주장': ['이영'],
#  '잇따르 밝혀내': ['지구'],
#  '있다 피부': ['비늘'],
#  '자연사 박물관': ['연구진'],
#  '자유 1993': ['쥬라기'],
#  '자유 연구진': ['지나'],
#  '장면 나오': ['네덜란드'],
#  '재구성 보행': ['모습'],
#  '적이 하지만': ['공룡'],
#  '전문 기자': ['ywlee'],
#  '전체 동시': ['개체'],
#  '제왕 노사': ['루스'],
#  '제이 peerj': ['연대'],
#  '조사 골반': ['꼬리'],
#  '조선 일보': ['뉴스', '앱으'],
#  '주기 감안': ['하면'],
#  '주목 공룡': ['꼬리'],
#  '주장 이영': ['과학'],
#  '주행 속도': ['시속'],
#  '쥐라기 후기': ['250', '6800'],
#  '쥬라기 공원': ['개봉', '로고'],
#  '증거 밝히': ['앞서'],
#  '지구 등장': ['25'],
#  '지구 지배': ['노사'],
#  '지나 16': ['사이언스'],
#  '지나 19': ['국제'],
#  '지나 21': ['왕립'],
#  '지배 노사': ['루스'],
#  '진면목 잇따르': ['밝혀내'],
#  '집단 사냥': ['만큼', '추정'],
#  '집안 총동원': ['최근'],
#  '찰스 교수': ['지나'],
#  '총동원 최근': ['과학자'],
#  '최고 기자': ['뉴스'],
#  '최근 과학자': ['그동안'],
#  '최대 가까이': ['몸무게'],
#  '추가 function': ['flash'],
#  '추산 하지만': ['네덜란드'],
#  '추정 네덜란드': ['스테르'],
#  '추정 만약': ['털이'],
#  '추정 빠르': ['부서지'],
#  '추정 쥐라기': ['후기'],
#  '충격 흡수': ['손상'],
#  '측정 통하': ['공룡'],
#  '캐나다 미국': ['몬태나'],
#  '캘리포니아 uc': ['버라'],
#  '캘리포니아 면적': ['3800'],
#  '컴퓨터 모델': ['만들'],
#  '코끼리 수가': ['이른바'],
#  '크기 연관짓': ['면적'],
#  '탄성 흔들리': ['주기'],
#  '털이 등에': ['일부'],
#  '토대 공룡': ['컴퓨터'],
#  '토대 사우': ['루스'],
#  '토대 재구성': ['보행'],
#  '토지 관리국': ['고생물'],
#  '통하 공룡': ['가족'],
#  '티투스 박사': ['아칸소', '유타주'],
#  '평균 보행': ['속도', '시속'],
#  '피부 비늘': ['영화'],
#  '피부 화석': ['조사'],
#  '피어 제이': ['peerj'],
#  '하면 평균': ['보행'],
#  '하지만 공룡': ['두뇌'],
#  '하지만 네덜란드': ['연구진'],
#  '하지만 명성': ['비하'],
#  '학술지 피어': ['제이'],
#  '학자 티투스': ['박사'],
#  '학회 오픈': ['사이언스'],
#  '함께 사냥': ['같이'],
#  '함수 추가': ['function'],
#  '혼자 다니': ['고독'],
#  '홍수 화석': ['사우'],
#  '화석 32': ['마리'],
#  '화석 꼬리': ['토대'],
#  '화석 남기': ['어렵'],
#  '화석 발견': ['집단'],
#  '화석 발굴': ['노사', '어르', '적이'],
#  '화석 사우': ['루스'],
#  '화석 조사': ['골반'],
#  '화석 토대': ['사우'],
#  '확인 보세': ['최고'],
#  '후기 250': ['동안'],
#  '후기 6800': ['6550'],
#  '휴스턴 자연사': ['박물관'],
#  '흔들리 균형': ['연구진'],
#  '흔들리 주기': ['감안'],
#  '흡수 손상': ['없이']}

# %%
def predict(argPreGram):
    rangeIdx = len(dicBase[argPreGram])
    idxPic = np.random.randint(0, rangeIdx)
    return(dicBase[argPreGram][idxPic])

predict("공룡 제왕")
# Out:
# '노사'

# %%
# 랜덤 시드 초기화.
np.random.seed(123)

# 사용자 입력 시드 문자열.
strMySeed = '근거 사우'            # 실제로 존재하는 (n-1)-Gram을 입력한다!
#strMySeed = 'in order' 

preGram  = strMySeed
strOut   = strMySeed                               # 출력 문자열 초기화.

while preGram in dicBase:
#for _ in np.arange(50):
    strOut += " " + predict(preGram)
    lstWord = nltk.word_tokenize(strOut)
    preGram = ' '.join(lstWord[-3+1:])                   # a_nm1_gram 갱신.
    
# 예측된 문자열 출력.
strOut
# Out:
# '근거 사우 루스 무리 화석 발견 집단 사냥 만큼 발달 어렵 비판 있다 피부 비늘 영화 사우 루스 얼마나 빠르 혼자 다니 고독 사냥꾼 집안 총동원 최근 과학자 그동안 미스터리 노사 루스 32 마리 아직 밝혀지 부분 uc 버클리 공룡 계의 스타 단연 영화 쥬라기 공원 로고 나오 노사 루스 32 마리 그치 그만큼 대형 육식 공룡 화석 남기 어렵 공룡 제왕 노사 루스 2017 미국 휴스턴 자연사 박물관 연구진 유일한 노사 루스 32 마리 그치 그만큼 대형 육식 공룡 화석 남기 어렵 공룡 제왕 노사 루스 32 마리 그치 그만큼 대형 육식 공룡 누스 덮이 연구 결과 나오 나오 사촌 노사 루스 2017 미국 휴스턴 자연사 박물관 연구진 유일한 노사 루스 화석 꼬리 토대 공룡 컴퓨터 모델 만들 꼬리 근육 토대 재구성 보행 모습 시속 km 사람 빠르 추정 네덜란드 스테르 자유 1993 쥬라기 공원 로고 나오 노사 루스 온전히 발굴 화석 32 마리 그치 그만큼 대형 육식 공룡 누스 덮이 연구 결과 나오 나오 사촌 노사 루스 온전히 발굴 화석 32 마리 아직 밝혀지 부분 uc 버클리 찰스 교수 지나 16 사이언스 무스 법칙 근거 사우 루스 보행 속도 시속 나오 달리기 이전 빠르 사우 루스 사람 따라잡 장면 나오 네덜란드 스테르 자유 연구진 지나 19 국제 학술지 피어 제이 peerj 연대 측정 통하 공룡 가족 동시 홍수 화석 사우 루스 사람 따라잡 장면 나오 네덜란드 스테르 자유 연구진 지나 19 국제 학술지 피어 제이 peerj 연대 측정 통하 공룡 가족 동시 홍수 화석 사우 루스 개체 밀도 신체 크기 연관짓 면적 코끼리 수가 이른바 무스 uc 버클리 찰스 교수 지나 16 사이언스 무스 법칙 근거 사우 루스 보행 속도 시속 10 추산 하지만 네덜란드 연구진 꼬리 충격 흡수 손상 없이 빨리 밝히 사우 루스 사람 따라잡 장면 나오 네덜란드 스테르 자유 1993 쥬라기 공원 로고 나오 노사 루스 진면목 잇따르 밝혀내 지구 등장 25 마리 서식 무리 화석 발견 집단 사냥 추정 쥐라기 후기 250 동안 지구 지배 노사 루스 온전히 발굴 화석 32 마리 그치 그만큼 대형 육식 공룡 화석 남기 어렵 공룡 제왕 노사 루스 몸길이 12 최대 가까이 몸무게 모든 동물 공포 몰아넣 하지만 명성 비하 아직 모르 사우 루스 세대 19 멸종 이르 250 동안 12 7000 세대 걸치 25 마리 서식 무리 화석 발견 집단 사냥 만큼 발달 어렵 비판 있다 피부 비늘 영화 사우 루스 얼마나 빠르 혼자 다니 고독 사냥꾼 집안 총동원 최근 과학자 그동안 미스터리 노사 루스 진면목 잇따르 밝혀내 지구 등장 25 마리 서식 무리 화석 발견 집단 사냥 추정 쥐라기 후기 6800 6550 사이 얼마나 공룡 캘리포니아 uc 버라 무스 교수 동물 개체 밀도 신체 크기 연관짓 면적 코끼리 수가 이른바 무스 uc 버클리 찰스 교수 지나 16 사이언스 무스 법칙 근거 사우 루스 사람 따라잡 장면 나오 네덜란드 스테르 자유 1993 쥬라기 공원 로고 나오 노사 루스 미스터리 2014 미국 토지 관리국 고생물 학자 티투스 박사 아칸소 대의 교수 공동 연구진 지나 19 국제 학술지 피어 제이 peerj 연대 측정 통하 공룡 가족 동시 홍수 화석 사우 루스 얼마나 빠르 혼자 다니 고독 사냥꾼 집안 총동원 최근 과학자 그동안 미스터리 노사 루스 피부 화석 조사 골반 꼬리 비늘 밝히 연구진 사우 보존 이전 단열 역할 사라지 추정 만약 털이 등에 일부 주장 이영 과학 전문 기자 ywlee chosun com 조선 일보 앱으 편하'

# %% [markdown]
# ### 보완사항
#     a. driveMy.get()의 안정성<br>
#     b. makeNGram에서 빈도수<br>
#     c. 최종 요약문 생성시 seed문 선택<br>
#     d. BaseDic Key Error 처리<br><br>
#     e. makeSent()에서 stopWord 인자로 변경<br>
# ### 추가 사항
#     a. WordCloud<br>
#     b. WebPage제작 ?
