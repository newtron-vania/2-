# %%
import numpy as np
import pandas as pd
import re
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Data 읽기 및 결측치 처리

# %%
df1 = pd.read_csv("winemag-data-130k-v2.csv")
print(df1.info())
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            92506 non-null   object
#  4   points                 129971 non-null  int64
#  5   price                  120975 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               108724 non-null  object
#  8   region_2               50511 non-null   object
#  9   taster_name            103727 non-null  object
#  10  taster_twitter_handle  98758 non-null   object
#  11  title                  129971 non-null  object
#  12  variety                129970 non-null  object
#  13  winery                 129971 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 13.9+ MB
# None
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
df1 = df1[df1["variety"].notnull() & df1["price"].notnull()]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120974 entries, 1 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             120974 non-null  int64
#  1   country                120915 non-null  object
#  2   description            120974 non-null  object
#  3   designation            86196 non-null   object
#  4   points                 120974 non-null  int64
#  5   price                  120974 non-null  float64
#  6   province               120915 non-null  object
#  7   region_1               101400 non-null  object
#  8   region_2               50292 non-null   object
#  9   taster_name            96479 non-null   object
#  10  taster_twitter_handle  91559 non-null   object
#  11  title                  120974 non-null  object
#  12  variety                120974 non-null  object
#  13  winery                 120974 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 13.8+ MB

# %% [markdown]
# ## "Description" Clean & lemmatize

# %%
def cleaning(argStr):
    argStr = argStr.lower()
    argStr = re.sub(r'\W',  ' ',argStr)
    argStr = re.sub(r'\s+', ' ',argStr)
    argStr = re.sub(r'\s$', '' ,argStr)
    return(argStr)

# %%
# df['features']=
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
lstCleanSent=[]
for sentence in df1.description:
    strWord = cleaning(sentence)
    strWord = re.sub('fruity', 'fruit', strWord)
    lstWord = nltk.word_tokenize(strWord)
    lstWord = [x.lower() for x in lstWord]
    lstWord = [x for x in lstWord if x not in stopwords.words('english')]
    lstWord = [stemmer.stem(x) for x in lstWord]
    lstWord = [lemmatizer.lemmatize(x) for x in lstWord]
    lstCleanSent.append(" ".join(lstWord))
print(len(lstCleanSent))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-82c8ec046b6d> in <module>
#       8     lstWord = nltk.word_tokenize(strWord)
#       9     lstWord = [x.lower() for x in lstWord]
# ---> 10     lstWord = [x for x in lstWord if x not in stopwords.words('english')]
#      11     lstWord = [stemmer.stem(x) for x in lstWord]
#      12     lstWord = [lemmatizer.lemmatize(x) for x in lstWord]
#
# <ipython-input-5-82c8ec046b6d> in <listcomp>(.0)
#       8     lstWord = nltk.word_tokenize(strWord)
#       9     lstWord = [x.lower() for x in lstWord]
# ---> 10     lstWord = [x for x in lstWord if x not in stopwords.words('english')]
#      11     lstWord = [stemmer.stem(x) for x in lstWord]
#      12     lstWord = [lemmatizer.lemmatize(x) for x in lstWord]
#
# C:\Anaconda3\lib\site-packages\nltk\corpus\reader\wordlist.py in words(self, fileids, ignore_lines_startswith)
#      21         return [
#      22             line
# ---> 23             for line in line_tokenize(self.raw(fileids))
#      24             if not line.startswith(ignore_lines_startswith)
#      25         ]
#
# C:\Anaconda3\lib\site-packages\nltk\corpus\reader\wordlist.py in raw(self, fileids)
#      30         elif isinstance(fileids, str):
#      31             fileids = [fileids]
# ---> 32         return concat([self.open(f).read() for f in fileids])
#      33
#      34
#
# C:\Anaconda3\lib\site-packages\nltk\corpus\reader\wordlist.py in <listcomp>(.0)
#      30         elif isinstance(fileids, str):
#      31             fileids = [fileids]
# ---> 32         return concat([self.open(f).read() for f in fileids])
#      33
#      34
#
# C:\Anaconda3\lib\site-packages\nltk\corpus\reader\api.py in open(self, file)
#     206         """
#     207         encoding = self.encoding(file)
# --> 208         stream = self._root.join(file).open(encoding)
#     209         return stream
#     210
#
# C:\Anaconda3\lib\site-packages\nltk\data.py in join(self, fileid)
#     335     def join(self, fileid):
#     336         _path = os.path.join(self._path, fileid)
# --> 337         return FileSystemPathPointer(_path)
#     338
#     339     def __repr__(self):
#
# C:\Anaconda3\lib\site-packages\nltk\compat.py in _decorator(*args, **kwargs)
#      39     def _decorator(*args, **kwargs):
#      40         args = (args[0], add_py3_data(args[1])) + args[2:]
# ---> 41         return init_func(*args, **kwargs)
#      42
#      43     return wraps(init_func)(_decorator)
#
# C:\Anaconda3\lib\site-packages\nltk\data.py in __init__(self, _path)
#     312
#     313         _path = os.path.abspath(_path)
# --> 314         if not os.path.exists(_path):
#     315             raise IOError("No such file or directory: %r" % _path)
#     316         self._path = _path
#
# C:\Anaconda3\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except (OSError, ValueError):
#      21         return False
#
# KeyboardInterrupt:

# %%
df1 = pd.read_pickle('winengram.pkl')

# %%
df1.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 1                            Avidagos      87   15.0           Douro
# 2                                 NaN      87   14.0          Oregon
# 3                Reserve Late Harvest      87   13.0        Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 5                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
# 5              Navarra                NaN   Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery  \
# 1      Portuguese Red  Quinta dos Avidagos
# 2          Pinot Gris            Rainstorm
# 3            Riesling           St. Julian
# 4          Pinot Noir         Sweet Cheeks
# 5  Tempranillo-Merlot               Tandem
#
#                                                lemma  \
# 1  ripe fruit wine smooth still structur firm tan...
# 2  tart snappi flavor lime flesh rind domin green...
# 3  pineappl rind lemon pith orang blossom start a...
# 4  much like regular bottl 2012 come across rathe...
# 5  blackberri raspberri aroma show typic navarran...
#
#                                              feature  \
# 1   ripe fruit wine firm tannin juici red berri f...
# 2                              green crisp acid wine
# 3                             lemon aroma palat note
# 4                                               wine
# 5   blackberri raspberri aroma green herb full bo...
#
#                                                NGram  \
# 1  acid-alreadi alreadi-drinkabl although-certain...
# 2  acid-underscor crisp-acid domin-green flavor-l...
# 3  aroma-palat astring-semidri bit-opul blossom-s...
# 4  2012-come across-rather bottl-2012 characteris...
# 5  acid-spici aroma-show blackberri-raspberri bod...
#
#                                         featureNGram
# 1   berri-fruit firm-tannin fruit-wine readi-drin...
# 2                                         crisp-acid
# 3
# 4
# 5                                          full-bodi

# %% [markdown]
# ## Description에서 유용한 단어 선별(Tfidf)

# %%
len(df1[df1["lemma"].str.contains("come")])
# Out:
# 7275

# %%
lstStopWord = ['also','charact','come','still','drink','years','feel', 'finish',
               'flavor','like','made','show','hint','offer','give', 'good', 'structur']
vectMy = TfidfVectorizer(max_features = 50, stop_words = lstStopWord )

X = vectMy.fit_transform(df1['lemma']).toarray()

print(vectMy.get_feature_names())
# Out:
# ['acid', 'age', 'appl', 'aroma', 'balanc', 'berri', 'black', 'blackberri', 'blend', 'bodi', 'bright', 'cabernet', 'cherri', 'citru', 'concentr', 'crisp', 'dark', 'dri', 'firm', 'fresh', 'fruit', 'full', 'green', 'herb', 'juici', 'lemon', 'light', 'miner', 'nose', 'note', 'oak', 'palat', 'peach', 'pepper', 'plum', 'raspberri', 'red', 'rich', 'ripe', 'soft', 'spice', 'sweet', 'tannin', 'textur', 'touch', 'vanilla', 'well', 'white', 'wine', 'year']

# %%
lstFeature = vectMy.get_feature_names()

def makeFeature(argStrD, arLstFt):
    strRes = ""
    lstDesc = argStrD.split(" ")
    for x in lstDesc:
        if x in lstFeature:
            strRes += " " + x
    return strRes

makeFeature(df1.loc[100, "lemma"], lstFeature)
# Out:
# ' fresh appl lemon full bodi rich balanc white'

# %%
df1["feature"]=df1["lemma"].apply(lambda x : makeFeature(x, lstFeature))
df1.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 1                            Avidagos      87   15.0           Douro
# 2                                 NaN      87   14.0          Oregon
# 3                Reserve Late Harvest      87   13.0        Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 5                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
# 5              Navarra                NaN   Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery  \
# 1      Portuguese Red  Quinta dos Avidagos
# 2          Pinot Gris            Rainstorm
# 3            Riesling           St. Julian
# 4          Pinot Noir         Sweet Cheeks
# 5  Tempranillo-Merlot               Tandem
#
#                                                lemma  \
# 1  ripe fruit wine smooth still structur firm tan...
# 2  tart snappi flavor lime flesh rind domin green...
# 3  pineappl rind lemon pith orang blossom start a...
# 4  much like regular bottl 2012 come across rathe...
# 5  blackberri raspberri aroma show typic navarran...
#
#                                              feature  \
# 1   ripe fruit wine firm tannin juici red berri f...
# 2                              green crisp acid wine
# 3                             lemon aroma palat note
# 4                                               wine
# 5   blackberri raspberri aroma green herb full bo...
#
#                                                NGram  \
# 1  acid-alreadi alreadi-drinkabl although-certain...
# 2  acid-underscor crisp-acid domin-green flavor-l...
# 3  aroma-palat astring-semidri bit-opul blossom-s...
# 4  2012-come across-rather bottl-2012 characteris...
# 5  acid-spici aroma-show blackberri-raspberri bod...
#
#                                         featureNGram
# 1   berri-fruit firm-tannin fruit-wine readi-drin...
# 2                                         crisp-acid
# 3
# 4
# 5                                          full-bodi

# %% [markdown]
# ## Lemmatize로 bigram 만들기(ITfidf)

# %%
def makeNGram(argLstSent, argNum = 3):
    vectMy = CountVectorizer(ngram_range=(argNum, argNum), analyzer="word")
    
    lstNGram = vectMy.fit(argLstSent).get_feature_names()
    # ar2NGramCnt = vectMy.transform(argLstSent).toarray()        # 결과는 array of array.
    # lstNGramCnt = list(ar2NGramCnt[0])                          # 단순한 리스트로 변환.
    return(lstNGram)

lstNGram = df1["lemma"].apply(lambda x : makeNGram([x], 2))

# %%
df1.loc[1, "lemma"]

# %%
lstNGram[1]

# %%
lstNGram2 = lstNGram.apply(lambda x : [re.sub(" ", "-", y) for y in x])
lstNGram3 = lstNGram2.apply(lambda x : " ".join(x))
lstNGram3

# %%
df1["NGram"] = lstNGram3

# %% [markdown]
# ## lemmatize 에서 유용한 단어 선별(Tfidf)

# %%
lstStopWord = []
vectMy = TfidfVectorizer(max_features = 50, token_pattern=r"(?u)\b\w\w+-\w+\b", stop_words = lstStopWord )

X = vectMy.fit_transform(df1['NGram']).toarray()

print(vectMy.get_feature_names())

# %%
lstFeatureNGram = vectMy.get_feature_names()

def makeFeatureNGram(argStrLemma, argLstFt):
    strRes = ""
    for x in argLstFt:
        x = re.sub("-", " ", x)
        if x in argStrLemma:
            strRes += " " + re.sub(" ", "-", x)
    return strRes
print(df1.loc[1, "lemma"])
makeFeatureNGram(df1.loc[1, "lemma"], lstFeatureNGram)

# %%
df1["featureNGram"]=df1["lemma"].apply(lambda x : makeFeatureNGram(x, lstFeatureNGram))
df1.head()

# %%
df1["featureNGram"].value_countss()

# %%
df1.to_pickle("winengram.pkl")

# %%
df1 = pd.read_pickle("winengram.pkl")
df1.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 1                            Avidagos      87   15.0           Douro
# 2                                 NaN      87   14.0          Oregon
# 3                Reserve Late Harvest      87   13.0        Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 5                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
# 5              Navarra                NaN   Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery  \
# 1      Portuguese Red  Quinta dos Avidagos
# 2          Pinot Gris            Rainstorm
# 3            Riesling           St. Julian
# 4          Pinot Noir         Sweet Cheeks
# 5  Tempranillo-Merlot               Tandem
#
#                                                lemma  \
# 1  ripe fruit wine smooth still structur firm tan...
# 2  tart snappi flavor lime flesh rind domin green...
# 3  pineappl rind lemon pith orang blossom start a...
# 4  much like regular bottl 2012 come across rathe...
# 5  blackberri raspberri aroma show typic navarran...
#
#                                              feature  \
# 1   ripe fruit wine firm tannin juici red berri f...
# 2                              green crisp acid wine
# 3                             lemon aroma palat note
# 4                                               wine
# 5   blackberri raspberri aroma green herb full bo...
#
#                                                NGram  \
# 1  acid-alreadi alreadi-drinkabl although-certain...
# 2  acid-underscor crisp-acid domin-green flavor-l...
# 3  aroma-palat astring-semidri bit-opul blossom-s...
# 4  2012-come across-rather bottl-2012 characteris...
# 5  acid-spici aroma-show blackberri-raspberri bod...
#
#                                         featureNGram
# 1   berri-fruit firm-tannin fruit-wine readi-drin...
# 2                                         crisp-acid
# 3
# 4
# 5                                          full-bodi

# %%
strBase = "ripe fruit wine firm tannin juici red berri"
lstTar = ["ripe",  "green"]

def isInStr(argLstTar, argStrBase):
    if any ((x in argStrBase) for x in argLstTar):
        return True
    else:
        return False
    
isInStr(lstTar, strBase)
# Out:
# True

# %%
lstFind = {"feature": ["ripe", "green", "acid"], "price":[30, 50]}

def cntFeature(argLstTarFt, argStrFt):
    cnt=0
    for x in argLstTarFt:
        if x in argStrFt:
            cnt += 1
    return cnt

print(df1.loc[2, "feature"])
cntFeature( lstFind["feature"], df1.loc[2, "feature"])
# Out:
#  green crisp acid wine
# 2

# %%
lstFind = {"feature": ["ripe", "green"], "price":[30, 50]}
def find(argDicTarget, argDfData):
    return (df1[  argDfData["feature"].apply(lambda x : isInStr(argDicTarget["feature"], x))
                & argDfData["price"].apply(lambda x : int(x) > argDicTarget["price"][0])
                & argDfData["price"].apply(lambda x : int(x) < argDicTarget["price"][1])
               ])

find(lstFind, df1).head()
# Out:
#      Unnamed: 0       country  \
# 121         121            US
# 125         125  South Africa
# 126         126        France
# 173         173            US
# 184         184            US
#
#                                            description  \
# 121  The vineyard is one of the better Chardonnay s...
# 125  Etienne Le Riche is a total Cabernet specialis...
# 126  Mid-gold color. Pronounced and enticing aromas...
# 173  This wine is bursting with gorgeous cherry fru...
# 184  This is a typical Sonoma Coast Chard in the br...
#
#                     designation  points  price      province  \
# 121        Stuhlmuller Vineyard      92   36.0    California
# 125  Cabernet Sauvignon Reserve      91   45.0  Stellenbosch
# 126           Vendages Tardives      91   48.0        Alsace
# 173                         NaN      91   38.0        Oregon
# 184                         NaN      88   35.0    California
#
#               region_1           region_2   taster_name taster_twitter_handle  \
# 121   Alexander Valley             Sonoma           NaN                   NaN
# 125                NaN                NaN    Roger Voss            @vossroger
# 126             Alsace                NaN           NaN                   NaN
# 173  Willamette Valley  Willamette Valley  Paul Gregutt           @paulgwine
# 184       Sonoma Coast             Sonoma           NaN                   NaN
#
#                                                  title             variety  \
# 121  Matrix 2007 Stuhlmuller Vineyard Chardonnay (A...          Chardonnay
# 125  Le Riche 2003 Cabernet Sauvignon Reserve Caber...  Cabernet Sauvignon
# 126  Pierre Sparr 2007 Vendages Tardives Gewurztram...      Gewürztraminer
# 173      Le Cadeau 2014 Pinot Noir (Willamette Valley)          Pinot Noir
# 184               Anaba 2007 Chardonnay (Sonoma Coast)          Chardonnay
#
#            winery                                              lemma  \
# 121        Matrix  vineyard one better chardonnay sourc alexand v...
# 125      Le Riche  etienn le rich total cabernet specialist tini ...
# 126  Pierre Sparr  mid gold color pronounc entic aroma ripe citru...
# 173     Le Cadeau  wine burst gorgeou cherri fruit forward luscio...
# 184         Anaba  typic sonoma coast chard bright acid firm ripe...
#
#                                                feature  \
# 121                  ripe wine oak vanilla balanc rich
# 125   rich cabernet wine cabernet fruit wine black ...
# 126   aroma ripe citru fruit note touch sweet spice...
# 173    wine cherri fruit tannin ripe acid fruit textur
# 184             bright acid firm ripe peach note spice
#
#                                                  NGram  \
# 121  add-butter alexand-valley balanc-classic bette...
# 125  000-case 2003-fruit across-wine best-sen black...
# 126  acid-medium aroma-ripe bodi-eleg citru-stone c...
# 173  acid-perfect buoy-upon burst-gorgeou cherri-fr...
# 184  acid-firm bright-acid buttercream-cinnamon cha...
#
#                             featureNGram
# 121
# 125                black-plum ripe-fruit
# 126   fresh-acid medium-bodi stone-fruit
# 173            cherri-fruit fruit-flavor
# 184                          bright-acid

# %%
lstFind = {"feature": ["ripe", "green", "fruit"],"variety" : ['Blend'], "price":[30, 50]}
def find(argDicTarget, argDfData):
    dfTmp = df1[  argDfData["feature"].apply(lambda x : isInStr(argDicTarget["feature"], x))
                & argDfData["variety"].apply(lambda x : isInStr(argDicTarget["variety"], x))
                & argDfData["price"].apply(lambda x : int(x) > argDicTarget["price"][0])
                & argDfData["price"].apply(lambda x : int(x) < argDicTarget["price"][1])
               ].copy()

    dfTmp["tmp"] = dfTmp["feature"].apply(lambda x: cntFeature(argDicTarget["feature"], x))
    
    return(dfTmp.sort_values(by=["tmp", "price", "points"], ascending=[False, True, False]))
    
find(lstFind, df1)[['country', 'description', 'designation','tmp','variety', 'points',
                    'price', 'province', 'region_1', 'taster_name',
                    'title', 'winery']].rename(columns={"region_1":"region"})
# Out:
#        country                                        description  \
# 13418   France  A big, fruity bold wine, packed with the ripes...
# 27789   France  A big, fruity bold wine, packed with the ripes...
# 45459   France  The estate is within the urban area of Bordeau...
# 115460  France  Crisp in sliced green-apple fruit, this Champa...
# 117710   Italy  A pretty mineral note appears at the very begi...
# ...        ...                                                ...
# 16927       US  Dry and intense in tannins, this blend of 50% ...
# 31807    Spain  Mature and sound on the bouquet, but more snap...
# 35756       US  A good but average red wine for drinking now. ...
# 25073   France  Barrel aged for 12 months, this 95% Merlot win...
# 63001   France  On the sweeter end of the Brut spectrum, this ...
#
#                          designation  tmp                     variety  points  \
# 13418              Pêche au Carrelet    3  Bordeaux-style White Blend      90
# 27789              Pêche au Carrelet    3  Bordeaux-style White Blend      90
# 45459                            NaN    3    Bordeaux-style Red Blend      93
# 115460                          Brut    3             Champagne Blend      90
# 117710                         Grale    3                   Red Blend      87
# ...                              ...  ...                         ...     ...
# 16927                            NaN    1       Rhône-style Red Blend      86
# 31807                        Reserva    1           Tempranillo Blend      86
# 35756                         Estate    1                   Red Blend      86
# 25073                            NaN    1    Bordeaux-style Red Blend      85
# 63001   Demoiselle Grande Cuvée Brut    1             Champagne Blend      85
#
#         price        province                     region        taster_name  \
# 13418    33.0        Bordeaux                     Graves         Roger Voss
# 27789    33.0        Bordeaux                     Graves         Roger Voss
# 45459    35.0        Bordeaux             Pessac-Léognan         Roger Voss
# 115460   35.0       Champagne                  Champagne         Roger Voss
# 117710   35.0         Tuscany                   Bolgheri                NaN
# ...       ...             ...                        ...                ...
# 16927    49.0      California                North Coast     Virginie Boone
# 31807    49.0  Northern Spain           Ribera del Duero  Michael Schachner
# 35756    49.0      California  Diamond Mountain District                NaN
# 25073    49.0        Bordeaux              Saint-Émilion         Roger Voss
# 63001    49.0       Champagne                  Champagne         Roger Voss
#
#                                                     title  \
# 13418   Château Haut-Peyrous 2008 Pêche au Carrelet  (...
# 27789   Château Haut-Peyrous 2008 Pêche au Carrelet  (...
# 45459         Château Picque Caillou 2014  Pessac-Léognan
# 115460                       Thiénot NV Brut  (Champagne)
# 117710                 Le Grascete 2009 Grale  (Bolgheri)
# ...                                                   ...
# 16927                 Honor Winery 2010 Red (North Coast)
# 31807            Resalte 2001 Reserva  (Ribera del Duero)
# 35756   A.S. Kiken 2009 Estate Red (Diamond Mountain D...
# 25073                  Château Valade 2012  Saint-Émilion
# 63001   Vranken NV Demoiselle Grande Cuvée Brut  (Cham...
#
#                         winery
# 13418     Château Haut-Peyrous
# 27789     Château Haut-Peyrous
# 45459   Château Picque Caillou
# 115460                 Thiénot
# 117710             Le Grascete
# ...                        ...
# 16927             Honor Winery
# 31807                  Resalte
# 35756               A.S. Kiken
# 25073           Château Valade
# 63001                  Vranken
#
# [2886 rows x 12 columns]

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery', 'lemma',
#        'feature', 'NGram', 'featureNGram'],
#       dtype='object')

# %%
Unnamed: 0  taster_twitter_handle region_2 features
